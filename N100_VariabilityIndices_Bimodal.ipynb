# %%
import numpy as np
from numpy import random
import pandas as pd
import math
import scipy.stats 
from scipy.stats import skew,spearmanr,kurtosis
from scipy import stats
import matplotlib.pyplot as plt

# %%
dataframe = pd.DataFrame(columns=['CV','SDL','PVplus','PVminus','PVprime','PVdblprime','PV','ADM',
                                  'sortval1','sortval2','sortval3','sortval4','sortval5',
                                     'sortval6','sortval7','sortval8','sortval9','sortval10',
                                     'sortval11','sortval12','sortval13','sortval14','sortval15',
                                     'sortval16','sortval17','sortval18','sortval19','sortval20',
                                     'sortval21','sortval22','sortval23','sortval24','sortval25',
                                     'sortval26','sortval27','sortval28','sortval29','sortval30',
                                     'sortval31','sortval32','sortval33','sortval34','sortval35',
                                     'sortval36','sortval37','sortval38','sortval39','sortval40',
                                     'sortval41','sortval42','sortval43','sortval44','sortval45',
                                     'sortval46','sortval47','sortval48','sortval49','sortval50',
                                     'sortval51','sortval52','sortval53','sortval54','sortval55',
                                     'sortval56','sortval57','sortval58','sortval59','sortval60',
                                     'sortval61','sortval62','sortval63','sortval64','sortval65',
                                     'sortval66','sortval67','sortval73','sortval74','sortval75',
                                     'sortval76','sortval77','sortval78','sortval79','sortval80',
                                     'sortval81','sortval82','sortval83','sortval84','sortval85',
                                     'sortval86','sortval87','sortval88','sortval89','sortval90',
                                     'sortval91','sortval92','sortval93','sortval94','sortval95',
                                     'sortval96','sortval97','sortval98','sortval99','sortval100',
                                  
                                  'value1','value2','value3','value4','value5',
                                  'value6','value7','value8','value9','value10',
                                  'value11','value12','value13','value14','value15',
                                  'value16','value17','value18','value19','value20',
                                  'value21','value22','value23','value24','value25',
                                  'value26','value27','value28','value29','value30',
                                  'value31','value32','value33','value34','value35',
                                  'value36','value37','value38','value39','value40',
                                  'value41','value42','value43','value44','value45',
                                  'value46','value47','value48','value49','value50',
                                  'value51','value52','value53','value54','value55',
                                  'value56','value57','value58','value59','value60',
                                  'value61','value62','value63','value64','value65',
                                  'value66','value67','value68','value69','value70',
                                  'value71','value72','value73','value74','value75',
                                  'value76','value77','value78','value79','value80',
                                  'value81','value82','value83','value84','value85',
                                  'value86','value87','value88','value89','value90',
                                  'value91','value92','value93','value94','value95',
                                  'value96','value97','value98','value99','value100'    
                                 ])

# %%
i=0
while i <=50000:
   
   
    m=random.choice([100,100])
    sd=random.choice([10,10])
    
    m2=random.choice([10,10])
    sd2=random.choice([1,1])
    
    value1=round(random.normal(m,sd),0)
    value2=round(random.normal(m,sd),0)
    value3=round(random.normal(m,sd),0)
    value4=round(random.normal(m,sd),0)
    value5=round(random.normal(m,sd),0)
    value6=round(random.normal(m,sd),0)
    value7=round(random.normal(m,sd),0)
    value8=round(random.normal(m,sd),0)
    value9=round(random.normal(m,sd),0)
    value10=round(random.normal(m,sd),0)
    
    value11=round(random.normal(m,sd),0)
    value12=round(random.normal(m,sd),0)
    value13=round(random.normal(m,sd),0)
    value14=round(random.normal(m,sd),0)
    value15=round(random.normal(m,sd),0)
    value16=round(random.normal(m,sd),0)
    value17=round(random.normal(m,sd),0)
    value18=round(random.normal(m,sd),0)
    value19=round(random.normal(m,sd),0)
    value20=round(random.normal(m,sd),0)
    
    value21=round(random.normal(m,sd),0)
    value22=round(random.normal(m,sd),0)
    value23=round(random.normal(m,sd),0)
    value24=round(random.normal(m,sd),0)
    value25=round(random.normal(m,sd),0)
    value26=round(random.normal(m,sd),0)
    value27=round(random.normal(m,sd),0)
    value28=round(random.normal(m,sd),0)
    value29=round(random.normal(m,sd),0)
    value30=round(random.normal(m,sd),0)
   
    value31=round(random.normal(m,sd),0)
    value32=round(random.normal(m,sd),0)
    value33=round(random.normal(m,sd),0)
    value34=round(random.normal(m,sd),0)
    value35=round(random.normal(m,sd),0)
    value36=round(random.normal(m,sd),0)
    value37=round(random.normal(m,sd),0)
    value38=round(random.normal(m,sd),0)
    value39=round(random.normal(m,sd),0)
    value40=round(random.normal(m,sd),0)
   
    value41=round(random.normal(m,sd),0)
    value42=round(random.normal(m,sd),0)
    value43=round(random.normal(m,sd),0)
    value44=round(random.normal(m,sd),0)
    value45=round(random.normal(m,sd),0)
    value46=round(random.normal(m,sd),0)
    value47=round(random.normal(m,sd),0)
    value48=round(random.normal(m,sd),0)
    value49=round(random.normal(m,sd),0)
    value50=round(random.normal(m,sd),0)
     
    value51=round(random.normal(m2,sd2),0)
    value52=round(random.normal(m2,sd2),0)
    value53=round(random.normal(m2,sd2),0)
    value54=round(random.normal(m2,sd2),0)
    value55=round(random.normal(m2,sd2),0)
    value56=round(random.normal(m2,sd2),0)
    value57=round(random.normal(m2,sd2),0)
    value58=round(random.normal(m2,sd2),0)
    value59=round(random.normal(m2,sd2),0)
    value60=round(random.normal(m2,sd2),0)
    
    value61=round(random.normal(m2,sd2),0)
    value62=round(random.normal(m2,sd2),0)
    value63=round(random.normal(m2,sd2),0)
    value64=round(random.normal(m2,sd2),0)
    value65=round(random.normal(m2,sd2),0)
    value66=round(random.normal(m2,sd2),0)
    value67=round(random.normal(m2,sd2),0)
    value68=round(random.normal(m2,sd2),0)
    value69=round(random.normal(m2,sd2),0)
    value70=round(random.normal(m2,sd2),0)
    
    value71=round(random.normal(m2,sd2),0)
    value72=round(random.normal(m2,sd2),0)
    value73=round(random.normal(m2,sd2),0)
    value74=round(random.normal(m2,sd2),0)
    value75=round(random.normal(m2,sd2),0)
    value76=round(random.normal(m2,sd2),0)
    value77=round(random.normal(m2,sd2),0)
    value78=round(random.normal(m2,sd2),0)
    value79=round(random.normal(m2,sd2),0)
    value80=round(random.normal(m2,sd2),0)
     
    value81=round(random.normal(m2,sd2),0)
    value82=round(random.normal(m2,sd2),0)
    value83=round(random.normal(m2,sd2),0)
    value84=round(random.normal(m2,sd2),0)
    value85=round(random.normal(m2,sd2),0)
    value86=round(random.normal(m2,sd2),0)
    value87=round(random.normal(m2,sd2),0)
    value88=round(random.normal(m2,sd2),0)
    value89=round(random.normal(m2,sd2),0)
    value90=round(random.normal(m2,sd2),0)
    
    value91=round(random.normal(m2,sd2),0)
    value92=round(random.normal(m2,sd2),0)
    value93=round(random.normal(m2,sd2),0)
    value94=round(random.normal(m2,sd2),0)
    value95=round(random.normal(m2,sd2),0)
    value96=round(random.normal(m2,sd2),0)
    value97=round(random.normal(m2,sd2),0)
    value98=round(random.normal(m2,sd2),0)
    value99=round(random.normal(m2,sd2),0)
    value100=round(random.normal(m2,sd2),0)
    

   
    
    sv =[value1,value2,value3,value4,value5,value6,value7,value8,value9,value10,
         value11,value12,value13,value14,value15,value16,value17,value18,value19,value20,
         value21,value22,value23,value24,value25,value26,value27,value28,value29,value30,
         value31,value32,value33,value34,value35,value36,value37,value38,value39,value40,
         value41,value42,value43,value44,value45,value46,value47,value48,value49,value50,
         value51,value52,value53,value54,value55,value56,value57,value58,value59,value60,
         value61,value62,value63,value64,value65,value66,value67,value68,value69,value70,
         value71,value72,value73,value74,value75,value76,value77,value78,value79,value80,
         value81,value82,value83,value84,value85,value86,value87,value88,value89,value90,
         value91,value92,value93,value94,value95,value96,value97,value98,value99,value100]
    
    sv.sort()
    summ=sum(sv)
    mean=np.mean(sv)
    stdv=np.std(sv)
    CV=stdv/mean

    sv1=sv[0]
    sv2=sv[1]
    sv3=sv[2]
    sv4=sv[3]
    sv5=sv[4]
    sv6=sv[5]
    sv7=sv[6]
    sv8=sv[7]
    sv9=sv[8]
    sv10=sv[9]
    
    sv11=sv[10]
    sv12=sv[11]
    sv13=sv[12]
    sv14=sv[13]
    sv15=sv[14]
    sv16=sv[15]
    sv17=sv[16]
    sv18=sv[17]
    sv19=sv[18]
    sv20=sv[19]
    
    sv21=sv[20]
    sv22=sv[21]
    sv23=sv[22]
    sv24=sv[23]
    sv25=sv[24]
    sv26=sv[25]
    sv27=sv[26]
    sv28=sv[27]
    sv29=sv[28]
    sv30=sv[29]
    
    sv31=sv[30]
    sv32=sv[31]
    sv33=sv[32]
    sv34=sv[33]
    sv35=sv[34]
    sv36=sv[35]
    sv37=sv[36]
    sv38=sv[37]
    sv39=sv[38]
    sv40=sv[39]
    
    sv41=sv[40]
    sv42=sv[41]
    sv43=sv[42]
    sv44=sv[43]
    sv45=sv[44]
    sv46=sv[45]
    sv47=sv[46]
    sv48=sv[47]
    sv49=sv[48]
    sv50=sv[49]
    
    sv51=sv[50]
    sv52=sv[51]
    sv53=sv[52]
    sv54=sv[53]
    sv55=sv[54]
    sv56=sv[55]
    sv57=sv[56]
    sv58=sv[57]
    sv59=sv[58]
    sv60=sv[59]
    
    sv61=sv[60]
    sv62=sv[61]
    sv63=sv[62]
    sv64=sv[63]
    sv65=sv[64]
    sv66=sv[65]
    sv67=sv[66]
    sv68=sv[67]
    sv69=sv[68]
    sv70=sv[69]
    
    sv71=sv[70]
    sv72=sv[71]
    sv73=sv[72]
    sv74=sv[73]
    sv75=sv[74]
    sv76=sv[75]
    sv77=sv[76]
    sv78=sv[77]
    sv79=sv[78]
    sv80=sv[79]
    
    sv81=sv[80]
    sv82=sv[81]
    sv83=sv[82]
    sv84=sv[83]
    sv85=sv[84]
    sv86=sv[85]
    sv87=sv[86]
    sv88=sv[87]
    sv89=sv[88]
    sv90=sv[89]
    
    sv91=sv[90]
    sv92=sv[91]
    sv93=sv[92]
    sv94=sv[93]
    sv95=sv[94]
    sv96=sv[95]
    sv97=sv[96]
    sv98=sv[97]
    sv99=sv[98]
    sv100=sv[99]
    
    ###################################################################################
    #SDL
          
    lvalue1=round(np.log(value1),50)
    lvalue2=round(np.log(value2),50)
    lvalue3=round(np.log(value3),50)
    lvalue4=round(np.log(value4),50)
    lvalue5=round(np.log(value5),50)
    lvalue6=round(np.log(value6),50)
    lvalue7=round(np.log(value7),50)
    lvalue8=round(np.log(value8),50)
    lvalue9=round(np.log(value9),50)
    lvalue10=round(np.log(value10),50)
    lvalue11=round(np.log(value11),50)
    lvalue12=round(np.log(value12),50)
    lvalue13=round(np.log(value13),50)
    lvalue14=round(np.log(value14),50)
    lvalue15=round(np.log(value15),50)
    lvalue16=round(np.log(value16),50)
    lvalue17=round(np.log(value17),50)
    lvalue18=round(np.log(value18),50)
    lvalue19=round(np.log(value19),50)
    lvalue20=round(np.log(value20),50)
    lvalue21=round(np.log(value21),50)
    lvalue22=round(np.log(value22),50)
    lvalue23=round(np.log(value23),50)
    lvalue24=round(np.log(value24),50)
    lvalue25=round(np.log(value25),50)
    lvalue26=round(np.log(value26),50)
    lvalue27=round(np.log(value27),50)
    lvalue28=round(np.log(value28),50)
    lvalue29=round(np.log(value29),50)
    lvalue30=round(np.log(value30),50)
    lvalue31=round(np.log(value31),50)
    lvalue32=round(np.log(value32),50)
    lvalue33=round(np.log(value33),50)
    lvalue34=round(np.log(value34),50)
    lvalue35=round(np.log(value35),50)
    lvalue36=round(np.log(value36),50)
    lvalue37=round(np.log(value37),50)
    lvalue38=round(np.log(value38),50)
    lvalue39=round(np.log(value39),50)
    lvalue40=round(np.log(value40),50)
    lvalue41=round(np.log(value41),50)
    lvalue42=round(np.log(value42),50)
    lvalue43=round(np.log(value43),50)
    lvalue44=round(np.log(value44),50)
    lvalue45=round(np.log(value45),50)
    lvalue46=round(np.log(value46),50)
    lvalue47=round(np.log(value47),50)
    lvalue48=round(np.log(value48),50)
    lvalue49=round(np.log(value49),50)
    lvalue50=round(np.log(value50),50)
    lvalue51=round(np.log(value51),50)
    lvalue52=round(np.log(value52),50)
    lvalue53=round(np.log(value53),50)
    lvalue54=round(np.log(value54),50)
    lvalue55=round(np.log(value55),50)
    lvalue56=round(np.log(value56),50)
    lvalue57=round(np.log(value57),50)
    lvalue58=round(np.log(value58),50)
    lvalue59=round(np.log(value59),50)
    lvalue60=round(np.log(value60),50)
    lvalue61=round(np.log(value61),50)
    lvalue62=round(np.log(value62),50)
    lvalue63=round(np.log(value63),50)
    lvalue64=round(np.log(value64),50)
    lvalue65=round(np.log(value65),50)
    lvalue66=round(np.log(value66),50)
    lvalue67=round(np.log(value67),50)
    lvalue68=round(np.log(value68),50)
    lvalue69=round(np.log(value69),50)
    lvalue70=round(np.log(value70),50)
    lvalue71=round(np.log(value71),50)
    lvalue72=round(np.log(value72),50)
    lvalue73=round(np.log(value73),50)
    lvalue74=round(np.log(value74),50)
    lvalue75=round(np.log(value75),50)
    lvalue76=round(np.log(value76),50)
    lvalue77=round(np.log(value77),50)
    lvalue78=round(np.log(value78),50)
    lvalue79=round(np.log(value79),50)
    lvalue80=round(np.log(value80),50)
    lvalue81=round(np.log(value81),50)
    lvalue82=round(np.log(value82),50)
    lvalue83=round(np.log(value83),50)
    lvalue84=round(np.log(value84),50)
    lvalue85=round(np.log(value85),50)
    lvalue86=round(np.log(value86),50)
    lvalue87=round(np.log(value87),50)
    lvalue88=round(np.log(value88),50)
    lvalue89=round(np.log(value89),50)
    lvalue90=round(np.log(value90),50)
    lvalue91=round(np.log(value91),50)
    lvalue92=round(np.log(value92),50)
    lvalue93=round(np.log(value93),50)
    lvalue94=round(np.log(value94),50)
    lvalue95=round(np.log(value95),50)
    lvalue96=round(np.log(value96),50)
    lvalue97=round(np.log(value97),50)
    lvalue98=round(np.log(value98),50)
    lvalue99=round(np.log(value99),50)
    lvalue100=round(np.log(value100),50)
    
    
    lvlist =[lvalue1,lvalue2,lvalue3,lvalue4,lvalue5,lvalue6,lvalue7,lvalue8,lvalue9,lvalue10,
             lvalue11,lvalue12,lvalue13,lvalue14,lvalue15,lvalue16,lvalue17,lvalue18,lvalue19,lvalue20,
             lvalue21,lvalue22,lvalue23,lvalue24,lvalue25,lvalue26,lvalue27,lvalue28,lvalue29,lvalue30,
             lvalue31,lvalue32,lvalue33,lvalue34,lvalue35,lvalue36,lvalue37,lvalue38,lvalue39,lvalue40,
             lvalue41,lvalue42,lvalue43,lvalue44,lvalue45,lvalue46,lvalue47,lvalue48,lvalue49,lvalue50,
             lvalue51,lvalue52,lvalue53,lvalue54,lvalue55,lvalue56,lvalue57,lvalue58,lvalue59,lvalue60,
             lvalue61,lvalue62,lvalue63,lvalue64,lvalue65,lvalue66,lvalue67,lvalue68,lvalue69,lvalue70,
             lvalue71,lvalue72,lvalue73,lvalue74,lvalue75,lvalue76,lvalue77,lvalue78,lvalue79,lvalue80,
             lvalue81,lvalue82,lvalue83,lvalue84,lvalue85,lvalue86,lvalue87,lvalue88,lvalue89,lvalue90,
             lvalue91,lvalue92,lvalue93,lvalue94,lvalue95,lvalue96,lvalue97,lvalue98,lvalue99,lvalue100
            ]
    
    SDL=np.std(lvlist) 
   
   
    
    ##########################################################################################
    #PV+
   
    abovesv1=np.sum(sv[1:100])
    abovesv2=np.sum(sv[2:100])
    abovesv3=np.sum(sv[3:100])
    abovesv4=np.sum(sv[4:100])
    abovesv5=np.sum(sv[5:100])
    abovesv6=np.sum(sv[6:100])       
    abovesv7=np.sum(sv[7:100])
    abovesv8=np.sum(sv[8:100])
    abovesv9=np.sum(sv[9:100])
    abovesv10=np.sum(sv[10:100])
    abovesv11=np.sum(sv[11:100])
    abovesv12=np.sum(sv[12:100])
    abovesv13=np.sum(sv[13:100])
    abovesv14=np.sum(sv[14:100])
    abovesv15=np.sum(sv[15:100])
    abovesv16=np.sum(sv[16:100])             
    abovesv17=np.sum(sv[17:100])     
    abovesv18=np.sum(sv[18:100])     
    abovesv19=np.sum(sv[19:100])    
    abovesv20=np.sum(sv[20:100])    
    abovesv21=np.sum(sv[21:100])                 
    abovesv22=np.sum(sv[22:100])     
    abovesv23=np.sum(sv[23:100]) 
    abovesv24=np.sum(sv[24:100])
    abovesv25=np.sum(sv[25:100])    
    abovesv26=np.sum(sv[26:100])         
    abovesv27=np.sum(sv[27:100]) 
    abovesv28=np.sum(sv[28:100])       
    abovesv29=np.sum(sv[29:100])     
    abovesv30=np.sum(sv[30:100]) 
    abovesv31=np.sum(sv[31:100])                
    abovesv32=np.sum(sv[32:100])  
    abovesv33=np.sum(sv[33:100])
    abovesv34=np.sum(sv[34:100])    
    abovesv35=np.sum(sv[35:100])    
    abovesv36=np.sum(sv[36:100])         
    abovesv37=np.sum(sv[37:100]) 
    abovesv38=np.sum(sv[38:100])       
    abovesv39=np.sum(sv[39:100])     
    abovesv40=np.sum(sv[40:100]) 
    abovesv41=np.sum(sv[41:100])                
    abovesv42=np.sum(sv[42:100])  
    abovesv43=np.sum(sv[43:100])
    abovesv44=np.sum(sv[44:100])  
    abovesv45=np.sum(sv[45:100]) 
    abovesv46=np.sum(sv[46:100])                
    abovesv47=np.sum(sv[47:100])  
    abovesv48=np.sum(sv[48:100])
    abovesv49=np.sum(sv[49:100]) 
    abovesv50=np.sum(sv[50:100]) 
    abovesv51=np.sum(sv[51:100])                
    abovesv52=np.sum(sv[52:100])  
    abovesv53=np.sum(sv[53:100])
    abovesv54=np.sum(sv[54:100])    
    abovesv55=np.sum(sv[55:100])    
    abovesv56=np.sum(sv[56:100])         
    abovesv57=np.sum(sv[57:100]) 
    abovesv58=np.sum(sv[58:100])       
    abovesv59=np.sum(sv[59:100])     
    abovesv60=np.sum(sv[60:100]) 
    abovesv61=np.sum(sv[61:100])                
    abovesv62=np.sum(sv[62:100])  
    abovesv63=np.sum(sv[63:100])
    abovesv64=np.sum(sv[64:100])  
    abovesv65=np.sum(sv[65:100]) 
    abovesv66=np.sum(sv[66:100])                
    abovesv67=np.sum(sv[67:100])  
    abovesv68=np.sum(sv[68:100])
    abovesv69=np.sum(sv[69:100])   
    abovesv70=np.sum(sv[70:100]) 
    abovesv71=np.sum(sv[71:100])                
    abovesv72=np.sum(sv[72:100])  
    abovesv73=np.sum(sv[73:100])
    abovesv74=np.sum(sv[74:100])  
    abovesv75=np.sum(sv[75:100]) 
    abovesv76=np.sum(sv[76:100])                
    abovesv77=np.sum(sv[77:100])  
    abovesv78=np.sum(sv[78:100])
    abovesv79=np.sum(sv[79:100]) 
    abovesv80=np.sum(sv[80:100]) 
    abovesv81=np.sum(sv[81:100])                
    abovesv82=np.sum(sv[82:100])  
    abovesv83=np.sum(sv[83:100])
    abovesv84=np.sum(sv[84:100])    
    abovesv85=np.sum(sv[85:100])    
    abovesv86=np.sum(sv[86:100])         
    abovesv87=np.sum(sv[87:100]) 
    abovesv88=np.sum(sv[88:100])       
    abovesv89=np.sum(sv[89:100])     
    abovesv90=np.sum(sv[90:100]) 
    abovesv91=np.sum(sv[91:100])                
    abovesv92=np.sum(sv[92:100])  
    abovesv93=np.sum(sv[93:100])
    abovesv94=np.sum(sv[94:100])  
    abovesv95=np.sum(sv[95:100]) 
    abovesv96=np.sum(sv[96:100])                
    abovesv97=np.sum(sv[97:100])  
    abovesv98=np.sum(sv[98:100])
    abovesv99=np.sum(sv[99:100])   
                                                  
    pdp1=abovesv1/sv1
    pdp2=abovesv2/sv2
    pdp3=abovesv3/sv3
    pdp4=abovesv4/sv4
    pdp5=abovesv5/sv5
    pdp6=abovesv6/sv6
    pdp7=abovesv7/sv7
    pdp8=abovesv8/sv8
    pdp9=abovesv9/sv9
    pdp10=abovesv10/sv10
    pdp11=abovesv11/sv11
    pdp12=abovesv12/sv12
    pdp13=abovesv13/sv13
    pdp14=abovesv14/sv14
    pdp15=abovesv15/sv15
    pdp16=abovesv16/sv16
    pdp17=abovesv17/sv17
    pdp18=abovesv18/sv18
    pdp19=abovesv19/sv19
    pdp20=abovesv20/sv20                 
    pdp21=abovesv21/sv21
    pdp22=abovesv22/sv22
    pdp23=abovesv23/sv23
    pdp24=abovesv24/sv24
    pdp25=abovesv25/sv25
    pdp26=abovesv26/sv26
    pdp27=abovesv27/sv27
    pdp28=abovesv28/sv28
    pdp29=abovesv29/sv29
    pdp30=abovesv30/sv30   
    pdp31=abovesv31/sv31
    pdp32=abovesv32/sv32
    pdp33=abovesv33/sv33
    pdp34=abovesv34/sv34
    pdp35=abovesv35/sv35
    pdp36=abovesv36/sv36
    pdp37=abovesv37/sv37
    pdp38=abovesv38/sv38
    pdp39=abovesv39/sv39
    pdp40=abovesv40/sv40   
    pdp41=abovesv41/sv41
    pdp42=abovesv42/sv42
    pdp43=abovesv43/sv43
    pdp44=abovesv44/sv44 
    pdp45=abovesv45/sv45   
    pdp46=abovesv46/sv46
    pdp47=abovesv47/sv47
    pdp48=abovesv48/sv48
    pdp49=abovesv49/sv49 
    pdp50=abovesv50/sv50   
    pdp51=abovesv51/sv51
    pdp52=abovesv52/sv52
    pdp53=abovesv53/sv53
    pdp54=abovesv54/sv54
    pdp55=abovesv55/sv55
    pdp56=abovesv56/sv56
    pdp57=abovesv57/sv57
    pdp58=abovesv58/sv58
    pdp59=abovesv59/sv59
    pdp60=abovesv60/sv60   
    pdp61=abovesv61/sv61
    pdp62=abovesv62/sv62
    pdp63=abovesv63/sv63
    pdp64=abovesv64/sv64 
    pdp65=abovesv65/sv65   
    pdp66=abovesv66/sv66
    pdp67=abovesv67/sv67
    pdp68=abovesv68/sv68
    pdp69=abovesv69/sv69

    pdp70=abovesv70/sv70   
    pdp71=abovesv71/sv71
    pdp72=abovesv72/sv72
    pdp73=abovesv73/sv73
    pdp74=abovesv74/sv74 
    pdp75=abovesv75/sv75   
    pdp76=abovesv76/sv76
    pdp77=abovesv77/sv77
    pdp78=abovesv78/sv78
    pdp79=abovesv79/sv79 
    pdp80=abovesv80/sv80   
    pdp81=abovesv81/sv81
    pdp82=abovesv82/sv82
    pdp83=abovesv83/sv83
    pdp84=abovesv84/sv84
    pdp85=abovesv85/sv85
    pdp86=abovesv86/sv86
    pdp87=abovesv87/sv87
    pdp88=abovesv88/sv88
    pdp89=abovesv89/sv89
    pdp90=abovesv90/sv90   
    pdp91=abovesv91/sv91
    pdp92=abovesv92/sv92
    pdp93=abovesv93/sv93
    pdp94=abovesv94/sv94 
    pdp95=abovesv95/sv95   
    pdp96=abovesv96/sv96
    pdp97=abovesv97/sv97
    pdp98=abovesv98/sv98
    pdp99=abovesv99/sv99

    
    PDPSum=(pdp1+pdp2+pdp3+pdp4+pdp5+pdp6+pdp7+pdp8+pdp9+pdp10+
              
              pdp91+pdp92+pdp93+pdp94+pdp95+pdp96+pdp97+pdp98+pdp99
             )-4950

    
    
    #######################################################################################
    #######################################################################################
    #PV-

    belowsv100=np.sum(sv[0:99])
    belowsv99=np.sum(sv[0:98])
    belowsv98=np.sum(sv[0:97])
    belowsv97=np.sum(sv[0:96])
    belowsv96=np.sum(sv[0:95])
    belowsv95=np.sum(sv[0:94])
    belowsv94=np.sum(sv[0:93])
    belowsv93=np.sum(sv[0:92])
    belowsv92=np.sum(sv[0:91])
    belowsv91=np.sum(sv[0:90])
    belowsv90=np.sum(sv[0:89])
    belowsv89=np.sum(sv[0:88])
    belowsv88=np.sum(sv[0:87])
    belowsv87=np.sum(sv[0:86])
    belowsv86=np.sum(sv[0:85])
    belowsv85=np.sum(sv[0:84])
    belowsv84=np.sum(sv[0:83])
    belowsv83=np.sum(sv[0:82])
    belowsv82=np.sum(sv[0:81])
    belowsv81=np.sum(sv[0:80])
    belowsv80=np.sum(sv[0:79])
    belowsv79=np.sum(sv[0:78])
    belowsv78=np.sum(sv[0:77])
    belowsv77=np.sum(sv[0:76])
    belowsv76=np.sum(sv[0:75])
    belowsv75=np.sum(sv[0:74])
    belowsv74=np.sum(sv[0:73])
    belowsv73=np.sum(sv[0:72])
    belowsv72=np.sum(sv[0:71])
    belowsv71=np.sum(sv[0:70])
    belowsv70=np.sum(sv[0:69])
    belowsv69=np.sum(sv[0:68])
    belowsv68=np.sum(sv[0:67])
    belowsv67=np.sum(sv[0:66])
    belowsv66=np.sum(sv[0:65])
    belowsv65=np.sum(sv[0:64])
    belowsv64=np.sum(sv[0:63])
    belowsv63=np.sum(sv[0:62])
    belowsv62=np.sum(sv[0:61])
    belowsv61=np.sum(sv[0:60])
    belowsv60=np.sum(sv[0:59])
    belowsv59=np.sum(sv[0:58])
    belowsv58=np.sum(sv[0:57])
    belowsv57=np.sum(sv[0:56])
    belowsv56=np.sum(sv[0:55])
    belowsv55=np.sum(sv[0:54])
    belowsv54=np.sum(sv[0:53])
    belowsv53=np.sum(sv[0:52])
    belowsv52=np.sum(sv[0:51])
    belowsv51=np.sum(sv[0:50])
    belowsv50=np.sum(sv[0:49])
    belowsv49=np.sum(sv[0:48])
    belowsv48=np.sum(sv[0:47])
    belowsv47=np.sum(sv[0:46])
    belowsv46=np.sum(sv[0:45])
    belowsv45=np.sum(sv[0:44])
    belowsv44=np.sum(sv[0:43])
    belowsv43=np.sum(sv[0:42])
    belowsv42=np.sum(sv[0:41])
    belowsv41=np.sum(sv[0:40])
    belowsv40=np.sum(sv[0:39])
    belowsv39=np.sum(sv[0:38])
    belowsv38=np.sum(sv[0:37])
    belowsv37=np.sum(sv[0:36])
    belowsv36=np.sum(sv[0:35])
    belowsv35=np.sum(sv[0:34])
    belowsv34=np.sum(sv[0:33])
    belowsv33=np.sum(sv[0:32])
    belowsv32=np.sum(sv[0:31])
    belowsv31=np.sum(sv[0:30])
    belowsv30=np.sum(sv[0:29])
    belowsv29=np.sum(sv[0:28])
    belowsv28=np.sum(sv[0:27])
    belowsv27=np.sum(sv[0:26])
    belowsv26=np.sum(sv[0:25])
    belowsv25=np.sum(sv[0:24])
    belowsv24=np.sum(sv[0:23])
    belowsv23=np.sum(sv[0:22])
    belowsv22=np.sum(sv[0:21])
    belowsv21=np.sum(sv[0:20])
    belowsv20=np.sum(sv[0:19])
    belowsv19=np.sum(sv[0:18])
    belowsv18=np.sum(sv[0:17])
    belowsv17=np.sum(sv[0:16])
    belowsv16=np.sum(sv[0:15])
    belowsv15=np.sum(sv[0:14])
    belowsv14=np.sum(sv[0:13])
    belowsv13=np.sum(sv[0:12])
    belowsv12=np.sum(sv[0:11])
    belowsv11=np.sum(sv[0:10])
    belowsv10=np.sum(sv[0:9])
    belowsv9=np.sum(sv[0:8])
    belowsv8=np.sum(sv[0:7])
    belowsv7=np.sum(sv[0:6])
    belowsv6=np.sum(sv[0:5])
    belowsv5=np.sum(sv[0:4])
    belowsv4=np.sum(sv[0:3])
    belowsv3=np.sum(sv[0:2])
    belowsv2=np.sum(sv[0:1])
    
    pdm100=belowsv100/sv100
    pdm99=belowsv99/sv99
    pdm98=belowsv98/sv98
    pdm97=belowsv97/sv97
    pdm96=belowsv96/sv96
    pdm95=belowsv95/sv95
    pdm94=belowsv94/sv94
    pdm93=belowsv93/sv93
    pdm92=belowsv92/sv92
    pdm91=belowsv91/sv91
    pdm90=belowsv90/sv90
    pdm89=belowsv89/sv89
    pdm88=belowsv88/sv88
    pdm87=belowsv87/sv87
    pdm86=belowsv86/sv86
    pdm85=belowsv85/sv85
    pdm84=belowsv84/sv84
    pdm83=belowsv83/sv83
    pdm82=belowsv82/sv82
    pdm81=belowsv81/sv81
    pdm80=belowsv80/sv80
    pdm79=belowsv79/sv79
    pdm78=belowsv78/sv78
    pdm77=belowsv77/sv77
    pdm76=belowsv76/sv76
    pdm75=belowsv75/sv75
    pdm74=belowsv74/sv74
    pdm73=belowsv73/sv73
    pdm72=belowsv72/sv72
    pdm71=belowsv71/sv71
    pdm70=belowsv70/sv70
    pdm69=belowsv69/sv69
    pdm68=belowsv68/sv68
    pdm67=belowsv67/sv67
    pdm66=belowsv66/sv66
    pdm65=belowsv65/sv65
    pdm64=belowsv64/sv64
    pdm63=belowsv63/sv63
    pdm62=belowsv62/sv62
    pdm61=belowsv61/sv61
    pdm60=belowsv60/sv60
    pdm59=belowsv59/sv59
    pdm58=belowsv58/sv58
    pdm57=belowsv57/sv57
    pdm56=belowsv56/sv56
    pdm55=belowsv55/sv55
    pdm54=belowsv54/sv54
    pdm53=belowsv53/sv53
    pdm52=belowsv52/sv52
    pdm51=belowsv51/sv51
    pdm50=belowsv50/sv50
    pdm49=belowsv49/sv49
    pdm48=belowsv48/sv48
    pdm47=belowsv47/sv47
    pdm46=belowsv46/sv46
    pdm45=belowsv45/sv45
    pdm44=belowsv44/sv44
    pdm43=belowsv43/sv43
    pdm42=belowsv42/sv42
    pdm41=belowsv41/sv41
    pdm40=belowsv40/sv40
    pdm39=belowsv39/sv39
    pdm38=belowsv38/sv38
    pdm37=belowsv37/sv37
    pdm36=belowsv36/sv36
    pdm35=belowsv35/sv35
    pdm34=belowsv34/sv34
    pdm33=belowsv33/sv33
    pdm32=belowsv32/sv32
    pdm31=belowsv31/sv31
    pdm30=belowsv30/sv30
    pdm29=belowsv29/sv29
    pdm28=belowsv28/sv28
    pdm27=belowsv27/sv27
    pdm26=belowsv26/sv26
    pdm25=belowsv25/sv25
    pdm24=belowsv24/sv24
    pdm23=belowsv23/sv23
    pdm22=belowsv22/sv22
    pdm21=belowsv21/sv21
    pdm20=belowsv20/sv20
    pdm19=belowsv19/sv19
    pdm18=belowsv18/sv18
    pdm17=belowsv17/sv17
    pdm16=belowsv16/sv16
    pdm15=belowsv15/sv15
    pdm14=belowsv14/sv14
    pdm13=belowsv13/sv13
    pdm12=belowsv12/sv12
    pdm11=belowsv11/sv11
    pdm10=belowsv10/sv10
    pdm9=belowsv9/sv9
    pdm8=belowsv8/sv8
    pdm7=belowsv7/sv7
    pdm6=belowsv6/sv6
    pdm5=belowsv5/sv5
    pdm4=belowsv4/sv4
    pdm3=belowsv3/sv3
    pdm2=belowsv2/sv2
    
    PDMSum=4950-(pdm2+pdm3+pdm4+pdm5+pdm6+pdm7+pdm8+pdm9+pdm10+
                   
                  )
    
    ##################################################
    PVplus=PDPSum/4950
    PVprime=1-(1/(1+PVplus))
    
    PVminus=PDMSum/4950
    PVdblprime=1-(1/(1+PVminus))
   
    PV=(PVprime+PVdblprime)/2
  
    ##############################################################################################
    #Average deviation from the mean
    
    md1=abs(value1-mean)
    md2=abs(value2-mean)
    md3=abs(value3-mean)
    md4=abs(value4-mean)
    md5=abs(value5-mean)
    md6=abs(value6-mean)
    md7=abs(value7-mean)
    md8=abs(value8-mean)
    md9=abs(value9-mean)
    md10=abs(value10-mean)
    
    md11=abs(value11-mean)
    md12=abs(value12-mean)
    md13=abs(value13-mean)
    md14=abs(value14-mean)
    md15=abs(value15-mean)
    md16=abs(value16-mean)
    md17=abs(value17-mean)
    md18=abs(value18-mean)
    md19=abs(value19-mean)
    md20=abs(value20-mean)
    
    md21=abs(value21-mean)
    md22=abs(value22-mean)
    md23=abs(value23-mean)
    md24=abs(value24-mean)
    md25=abs(value25-mean)
    md26=abs(value26-mean)
    md27=abs(value27-mean)
    md28=abs(value28-mean)
    md29=abs(value29-mean)
    md30=abs(value30-mean)
    
    md31=abs(value31-mean)
    md32=abs(value32-mean)
    md33=abs(value33-mean)
    md34=abs(value34-mean)
    md35=abs(value35-mean)
    md36=abs(value36-mean)
    md37=abs(value37-mean)
    md38=abs(value38-mean)
    md39=abs(value39-mean)
    md40=abs(value40-mean)
    
    md41=abs(value41-mean)
    md42=abs(value42-mean)
    md43=abs(value43-mean)
    md44=abs(value44-mean)
    md45=abs(value45-mean)
    md46=abs(value46-mean)
    md47=abs(value47-mean)
    md48=abs(value48-mean)
    md49=abs(value49-mean)
    md50=abs(value50-mean)
    
    md51=abs(value51-mean)
    md52=abs(value52-mean)
    md53=abs(value53-mean)
    md54=abs(value54-mean)
    md55=abs(value55-mean)
    md56=abs(value56-mean)
    md57=abs(value57-mean)
    md58=abs(value58-mean)
    md59=abs(value59-mean)
    md60=abs(value60-mean)
    
    md61=abs(value61-mean)
    md62=abs(value62-mean)
    md63=abs(value63-mean)
    md64=abs(value64-mean)
    md65=abs(value65-mean)
    md66=abs(value66-mean)
    md67=abs(value67-mean)
    md68=abs(value68-mean)
    md69=abs(value69-mean)
    md70=abs(value70-mean)
    
    md71=abs(value71-mean)
    md72=abs(value72-mean)
    md73=abs(value73-mean)
    md74=abs(value74-mean)
    md75=abs(value75-mean)
    md76=abs(value76-mean)
    md77=abs(value77-mean)
    md78=abs(value78-mean)
    md79=abs(value79-mean)
    md80=abs(value80-mean)
    
    md81=abs(value81-mean)
    md82=abs(value82-mean)
    md83=abs(value83-mean)
    md84=abs(value84-mean)
    md85=abs(value85-mean)
    md86=abs(value86-mean)
    md87=abs(value87-mean)
    md88=abs(value88-mean)
    md89=abs(value89-mean)
    md90=abs(value90-mean)
    
    md91=abs(value91-mean)
    md92=abs(value92-mean)
    md93=abs(value93-mean)
    md94=abs(value94-mean)
    md95=abs(value95-mean)
    md96=abs(value96-mean)
    md97=abs(value97-mean)
    md98=abs(value98-mean)
    md99=abs(value99-mean)
    md100=abs(value100-mean)
    
    ADM=( 
         md81+md82+md83+md84+md85+md86+md87+md88+md89+md90+md91+md92+md93+md94+md95+md96+md97+md98+md99+md100
        )/100
    
    
   
    #################################################################################
    i+=1 
    
    dataframe.loc[len(dataframe)] = (CV,SDL,PVplus,PVminus,PVprime,PVdblprime,PV,ADM,
                                     sv1,sv2,sv3,sv4,sv5,
                                     sv6,sv7,sv8,sv9,sv10,
                                     sv11,sv12,sv13,sv14,sv15,
                                     sv16,sv17,sv18,sv19,sv20,
                                     sv21,sv22,sv23,sv24,sv25,
                                     sv26,sv27,sv28,sv29,sv30,
                                     sv31,sv32,sv33,sv34,sv35,
                                     sv36,sv37,sv38,sv39,sv40,
                                     sv41,sv42,sv43,sv44,sv45,
                                     sv46,sv47,sv48,sv49,sv50,
                                     sv51,sv52,sv53,sv54,sv55,
                                     sv56,sv57,sv58,sv59,sv60,
                                     sv61,sv62,sv63,sv64,sv65,
                                     sv66,sv67,sv73,sv74,sv75,
                                     sv76,sv77,sv78,sv79,sv80,
                                     sv81,sv82,sv83,sv84,sv85,
                                     sv86,sv87,sv88,sv89,sv90,
                                     sv91,sv92,sv93,sv94,sv95,
                                     sv96,sv97,sv98,sv99,sv100,
                                     
                                     
                                     value1,value2,value3,value4,value5,
                                     value6,value7,value8,value9,value10,
                                     value11,value12,value13,value14,value15,
                                     value16,value17,value18,value19,value20,
                                     value21,value22,value23,value24,value25,
                                     value26,value27,value28,value29,value30,
                                     value31,value32,value33,value34,value35,
                                     value36,value37,value38,value39,value40,
                                     value41,value42,value43,value44,value45,
                                     value46,value47,value48,value49,value50,
                                     value51,value52,value53,value54,value55,
                                     value56,value57,value58,value59,value60,
                                     value61,value62,value63,value64,value65,
                                     value66,value67,value68,value69,value70,
                                     value71,value72,value73,value74,value75,
                                     value76,value77,value78,value79,value80,
                                     value81,value82,value83,value84,value85,
                                     value86,value87,value88,value89,value90,
                                     value91,value92,value93,value94,value95,
                                     value96,value97,value98,value99,value100
                                     )

# %%
dataframe
# Out:
#              CV       SDL    PVplus   PVminus   PVprime  PVdblprime        PV  \
# 0      0.823898  1.140407  4.504227  0.503418  0.818321    0.334849  0.576585
# 1      0.831559  1.166242  4.766846  0.505799  0.826595    0.335901  0.581248
# 2      0.825365  1.148402  4.575450  0.499159  0.820642    0.332959  0.576801
# 3      0.833779  1.171782  4.821755  0.504178  0.828230    0.335185  0.581708
# 4      0.833184  1.164653  4.764428  0.513028  0.826522    0.339074  0.582798
# ...         ...       ...       ...       ...       ...         ...       ...
# 49996  0.828668  1.149908  4.605204  0.507938  0.821594    0.336843  0.579219
# 49997  0.825496  1.153606  4.636753  0.504599  0.822593    0.335371  0.578982
# 49998  0.831208  1.166304  4.772608  0.508995  0.826768    0.337307  0.582038
# 49999  0.823974  1.140598  4.509822  0.505763  0.818506    0.335885  0.577195
# 50000  0.823989  1.144415  4.542722  0.503193  0.819583    0.334749  0.577166
#
# ...

# %%
#dataframe.to_excel(r'C:/Documents/.../N100_VariabilityIndices_Bimodal.xlsx', sheet_name='Sheet1', index = True)

# %%
CorrCoeff=np.corrcoef(dataframe['CV'],dataframe['ADM'])[0,1]
Tau, piTau = stats.kendalltau(dataframe['CV'],dataframe['ADM'])
Rho, piRho =stats.spearmanr(dataframe['CV'],dataframe['ADM'])

CorrCoeff2=np.corrcoef(dataframe['SDL'],dataframe['ADM'])[0,1]
Tau2, piTau2 = stats.kendalltau(dataframe['SDL'],dataframe['ADM'])
Rho2, piRho2 =stats.spearmanr(dataframe['SDL'],dataframe['ADM'])

CorrCoeff3=np.corrcoef(dataframe['PVminus'],dataframe['ADM'])[0,1]
Tau3, piTau3 = stats.kendalltau(dataframe['PVminus'],dataframe['ADM'])
Rho3, piRho3 =stats.spearmanr(dataframe['PVminus'],dataframe['ADM'])

CorrCoeff4=np.corrcoef(dataframe['PV'],dataframe['ADM'])[0,1]
Tau4, piTau4 = stats.kendalltau(dataframe['PV'],dataframe['ADM'])
Rho4, piRho4 =stats.spearmanr(dataframe['PV'],dataframe['ADM'])

# %%
CorrCoeff, Tau, Rho
# Out:
# (0.61193235363375, 0.41951288464816366, 0.5933985150991222)

# %%
CorrCoeff2, Tau2, Rho2
# Out:
# (0.7528967875272856, 0.5425257535195807, 0.7358746209116283)

# %%
CorrCoeff3, Tau3, Rho3
# Out:
# (0.12848397907103626, 0.08172074559086416, 0.12217890175135761)

# %%
CorrCoeff4, Tau4, Rho4
# Out:
# (0.6279291540612576, 0.4315864131292626, 0.6083254810386751)

# %%
plt.hist(dataframe['CV'], color = 'blue', edgecolor = 'black',
         bins = int(100/1))
# Add labels
plt.title('Histogram of CV')
plt.xlabel('CV')
plt.ylabel('Density')
plt.show()
cv=dataframe['CV']
print('\nSkewness for data : ', skew(cv))
print('\nKurtosis for data : ', kurtosis(cv)) 
print('\nMean for data : ', np.mean(cv)) 
print('\nMedian for data : ', np.median(cv)) 
print('\nMin for data : ', min(cv)) 
print('\nMax for data : ', max(cv)) 
print('\nVar for data : ', np.var(cv)) 
print('\nStandard deviation for data : ', np.std(cv))
print('\nPercentiles left25,righ95,right99 for data : ',np.percentile(cv,[50,95,99]))
# Out:
# Skewness for data :  -0.013507881956514523
#
# Kurtosis for data :  0.03947300794430442
#
# Mean for data :  0.8281060265228388
#
# Median for data :  0.8281122714910593
#
# Min for data :  0.8125849728324804
#
# Max for data :  0.8439373781951718
#
# Var for data :  1.403809768539035e-05
#
# Standard deviation for data :  0.003746744945334597
#
# Percentiles left25,righ95,right99 for data :  [0.82811227 0.83427019 0.83681384]

# %%
plt.hist(dataframe['ADM'], color = 'blue', edgecolor = 'black',
         bins = int(100/1))
# Add labels
plt.title('Histogram of ADM')
plt.xlabel('ADM')
plt.ylabel('Density')
plt.show()
adm=dataframe['ADM']
print('\nSkewness for data : ', skew(adm))
print('\nKurtosis for data : ', kurtosis(adm)) 
print('\nMean for data : ', np.mean(adm)) 
print('\nMedian for data : ', np.median(adm)) 
print('\nMin for data : ', min(adm)) 
print('\nMax for data : ', max(adm)) 
print('\nVar for data : ', np.var(adm)) 
print('\nStandard deviation for data : ', np.std(adm))
print('\nPercentiles left25,righ95,right99 for data : ',np.percentile(adm,[50,95,99]))
# Out:
# Skewness for data :  -0.0004246134416806555
#
# Kurtosis for data :  0.04444477523659218
#
# Mean for data :  44.996497902041995
#
# Median for data :  44.99999999999997
#
# Min for data :  42.09000000000002
#
# Max for data :  48.63000000000002
#
# Var for data :  0.5084610391590205
#
# Standard deviation for data :  0.7130645406686694
#
# Percentiles left25,righ95,right99 for data :  [45.   46.17 46.67]

# %%
plt.hist(dataframe['SDL'], color = 'blue', edgecolor = 'black',
         bins = int(100/1))
# Add labels
plt.title('Histogram of SDL')
plt.xlabel('SDL')
plt.ylabel('Density')
plt.show()
sdl=dataframe['SDL']
print('\nSkewness for data : ', skew(sdl))
print('\nKurtosis for data : ', kurtosis(sdl)) 
print('\nMean for data : ', np.mean(sdl)) 
print('\nMedian for data : ', np.median(sdl)) 
print('\nMin for data : ', min(sdl)) 
print('\nMax for data : ', max(sdl)) 
print('\nVar for data : ', np.var(sdl)) 
print('\nStandard deviation for data : ', np.std(sdl))
print('\nPercentiles left25,righ95,right99 for data : ',np.percentile(cv,[50,95,99]))
# Out:
# Skewness for data :  0.014581260207360131
#
# Kurtosis for data :  0.03342113354051568
#
# Mean for data :  1.1560060206172618
#
# Median for data :  1.1559311124939462
#
# Min for data :  1.114165662642539
#
# Max for data :  1.2022741854177015
#
# Var for data :  0.00010663576605186345
#
# Standard deviation for data :  0.010326459511946166
#
# Percentiles left25,righ95,right99 for data :  [0.82811227 0.83427019 0.83681384]

# %%
plt.hist(dataframe['PVminus'], color = 'blue', edgecolor = 'black',
         bins = int(100/1))
# Add labels
plt.title('Histogram of PVminus')
plt.xlabel('PVminus')
plt.ylabel('Density')
plt.show()
pvm=dataframe['PVminus']
print('\nSkewness for data : ', skew(pvm))
print('\nKurtosis for data : ', kurtosis(pvm)) 
print('\nMean for data : ', np.mean(pvm)) 
print('\nMedian for data : ', np.median(pvm)) 
print('\nMin for data : ', min(pvm)) 
print('\nMax for data : ', max(pvm)) 
print('\nVar for data : ', np.var(pvm)) 
print('\nStandard deviation for data : ', np.std(pvm))
print('\nPercentiles left25,righ95,right99 for data : ',np.percentile(pvm,[50,95,99]))
# Out:
# Skewness for data :  0.01854763115225275
#
# Kurtosis for data :  0.020275903040781973
#
# Mean for data :  0.5054428382611745
#
# Median for data :  0.5054168871114022
#
# Min for data :  0.4870867329782346
#
# Max for data :  0.5222281291566707
#
# Var for data :  1.4164822063478605e-05
#
# Standard deviation for data :  0.003763618214362159
#
# Percentiles left25,righ95,right99 for data :  [0.50541689 0.51163104 0.51421971]

# %%
plt.hist(dataframe['PV'], color = 'blue', edgecolor = 'black',
         bins = int(100/1))
# Add labels
plt.title('Histogram of PV')
plt.xlabel('PV')
plt.ylabel('Density')
plt.show()
pv=dataframe['PV']
print('\nSkewness for data : ', skew(pv))
print('\nKurtosis for data : ', kurtosis(pv)) 
print('\nMean for data : ', np.mean(pv)) 
print('\nMedian for data : ', np.median(pv)) 
print('\nMin for data : ', min(pv)) 
print('\nMax for data : ', max(pv)) 
print('\nVar for data : ', np.var(pv)) 
print('\nStandard deviation for data : ', np.std(pv))
print('\nPercentiles left25,righ95,right99 for data : ',np.percentile(pv,[50,95,99]))
# Out:
# Skewness for data :  -0.028163012489507998
#
# Kurtosis for data :  0.03732063837663846
#
# Mean for data :  0.579555922903512
#
# Median for data :  0.5795552415043086
#
# Min for data :  0.5709187270780245
#
# Max for data :  0.5886972801351917
#
# Var for data :  4.562788981403922e-06
#
# Standard deviation for data :  0.0021360685806883456
#
# Percentiles left25,righ95,right99 for data :  [0.57955524 0.58306035 0.58448753]

# %%
plt.hist(dataframe['PVprime'], color = 'blue', edgecolor = 'black',
         bins = int(100/1))
# Add labels
plt.title('Histogram of PVprime')
plt.xlabel('PVprime')
plt.ylabel('Density')
plt.show()
pvpr=dataframe['PVprime']
print('\nSkewness for data : ', skew(pvpr))
print('\nKurtosis for data : ', kurtosis(pvpr)) 
print('\nMean for data : ', np.mean(pvpr)) 
print('\nMedian for data : ', np.median(pvpr)) 
print('\nMin for data : ', min(pvpr)) 
print('\nMax for data : ', max(pvpr)) 
print('\nVar for data : ', np.var(pvpr)) 
print('\nStandard deviation for data : ', np.std(pvpr))
print('\nPercentiles left25,righ95,right99 for data : ',np.percentile(pvpr,[50,95,99]))
# Out:
# Skewness for data :  -0.036532590418233264
#
# Kurtosis for data :  0.039946060813197626
#
# Mean for data :  0.8233723706504072
#
# Median for data :  0.8233741266960795
#
# Min for data :  0.8096570502879546
#
# Max for data :  0.8376532650532011
#
# Var for data :  1.1048738662462298e-05
#
# Standard deviation for data :  0.0033239642992159675
#
# Percentiles left25,righ95,right99 for data :  [0.82337413 0.82883958 0.83103625]

# %%
plt.hist(dataframe['PVplus'], color = 'blue', edgecolor = 'black',
         bins = int(100/1))
# Add labels
plt.title('Histogram of PVplus')
plt.xlabel('PVplus')
plt.ylabel('Density')
plt.show()
pvp=dataframe['PVplus']
print('\nSkewness for data : ', skew(pvp))
print('\nKurtosis for data : ', kurtosis(pvp)) 
print('\nMean for data : ', np.mean(pvp)) 
print('\nMedian for data : ', np.median(pvp)) 
print('\nMin for data : ', min(pvp)) 
print('\nMax for data : ', max(pvp)) 
print('\nVar for data : ', np.var(pvp)) 
print('\nStandard deviation for data : ', np.std(pvp))
print('\nPercentiles left25,righ95,right99 for data : ',np.percentile(pvp,[50,95,99]))
# Out:
# Skewness for data :  0.0784478109192927
#
# Kurtosis for data :  0.044796455308731886
#
# Mean for data :  4.663634267213951
#
# Median for data :  4.661684674471771
#
# Min for data :  4.253675019289237
#
# Max for data :  5.15965575364174
#
# Var for data :  0.01136916056795728
#
# Standard deviation for data :  0.10662626584457172
#
# Percentiles left25,righ95,right99 for data :  [4.66168467 4.84247215 4.91842915]
