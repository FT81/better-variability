# %%
import numpy as np
from numpy import random
import pandas as pd
import matplotlib.pyplot as plt
import math
import statistics as stats
import scipy.stats 
from scipy.stats import skew,spearmanr,kurtosis
from scipy import stats
import matplotlib.pyplot as plt

# %%
dataframe2 = pd.DataFrame(columns=['MPV_S','MPV_D','MPV',
                                       'PV_S','PV_I','PV_D','PV',
                                       'Heath','CV','SDL','ADM','mean',
                                       'value1','value2','value3','value4','value5',
                                       'value6','value7','value8','value9','value10',
                                       'value11','value12','value13','value14','value15',
                                       'value16','value17','value18','value19','value20',
                                       'value21','value22','value23','value24','value25',
                                       'value26','value27','value28','value29','value30',
                                       'value31','value32','value33','value34','value35',
                                       'value36','value37','value38','value39','value40',
                                       'value41','value42','value43','value44','value45',
                                       'value46','value47','value48','value49','value50',
                                       'value51','value52','value53','value54','value55',
                                       'value56','value57','value58','value59','value60',
                                       'value61','value62','value63','value64','value65',
                                       'value66','value67','value68','value69','value70',
                                       'value71','value72','value73','value74','value75',
                                       'value76','value77','value78','value79','value80',
                                       'value81','value82','value83','value84','value85',
                                       'value86','value87','value88','value89','value90',
                                       'value91','value92','value93','value94','value95',
                                       'value96','value97','value98','value99','value100'
                                      
                                  ])

# %%
i=0
while i <=10000:
   
    
    m=random.choice([100,100])
    sd=random.choice([10,10])
    
    m2=random.choice([10,10])
    sd2=random.choice([1,1])
    
    value1=random.normal(m,sd)
    value2=random.normal(m,sd)
    value3=random.normal(m,sd)
    value4=random.normal(m,sd)
    value5=random.normal(m,sd)
    value6=random.normal(m,sd)
    value7=random.normal(m,sd)
    value8=random.normal(m,sd)
    value9=random.normal(m,sd)
    value10=random.normal(m,sd)
    
    value11=random.normal(m,sd)
    value12=random.normal(m,sd)
    value13=random.normal(m,sd)
    value14=random.normal(m,sd)
    value15=random.normal(m,sd)
    value16=random.normal(m,sd)
    value17=random.normal(m,sd)
    value18=random.normal(m,sd)
    value19=random.normal(m,sd)
    value20=random.normal(m,sd)
    
    value21=random.normal(m,sd)
    value22=random.normal(m,sd)
    value23=random.normal(m,sd)
    value24=random.normal(m,sd)
    value25=random.normal(m,sd)
    value26=random.normal(m,sd)
    value27=random.normal(m,sd)
    value28=random.normal(m,sd)
    value29=random.normal(m,sd)
    value30=random.normal(m,sd)
   
    value31=random.normal(m,sd)
    value32=random.normal(m,sd)
    value33=random.normal(m,sd)
    value34=random.normal(m,sd)
    value35=random.normal(m,sd)
    value36=random.normal(m,sd)
    value37=random.normal(m,sd)
    value38=random.normal(m,sd)
    value39=random.normal(m,sd)
    value40=random.normal(m,sd)
   
    value41=random.normal(m,sd)
    value42=random.normal(m,sd)
    value43=random.normal(m,sd)
    value44=random.normal(m,sd)
    value45=random.normal(m,sd)
    value46=random.normal(m,sd)
    value47=random.normal(m,sd)
    value48=random.normal(m,sd)
    value49=random.normal(m,sd)
    value50=random.normal(m,sd)
     
    value51=random.normal(m2,sd2)
    value52=random.normal(m2,sd2)
    value53=random.normal(m2,sd2)
    value54=random.normal(m2,sd2)
    value55=random.normal(m2,sd2)
    value56=random.normal(m2,sd2)
    value57=random.normal(m2,sd2)
    value58=random.normal(m2,sd2)
    value59=random.normal(m2,sd2)
    value60=random.normal(m2,sd2)
    
    value61=random.normal(m2,sd2)
    value62=random.normal(m2,sd2)
    value63=random.normal(m2,sd2)
    value64=random.normal(m2,sd2)
    value65=random.normal(m2,sd2)
    value66=random.normal(m2,sd2)
    value67=random.normal(m2,sd2)
    value68=random.normal(m2,sd2)
    value69=random.normal(m2,sd2)
    value70=random.normal(m2,sd2)
    
    value71=random.normal(m2,sd2)
    value72=random.normal(m2,sd2)
    value73=random.normal(m2,sd2)
    value74=random.normal(m2,sd2)
    value75=random.normal(m2,sd2)
    value76=random.normal(m2,sd2)
    value77=random.normal(m2,sd2)
    value78=random.normal(m2,sd2)
    value79=random.normal(m2,sd2)
    value80=random.normal(m2,sd2)
     
    value81=random.normal(m2,sd2)
    value82=random.normal(m2,sd2)
    value83=random.normal(m2,sd2)
    value84=random.normal(m2,sd2)
    value85=random.normal(m2,sd2)
    value86=random.normal(m2,sd2)
    value87=random.normal(m2,sd2)
    value88=random.normal(m2,sd2)
    value89=random.normal(m2,sd2)
    value90=random.normal(m2,sd2)
    
    value91=random.normal(m2,sd2)
    value92=random.normal(m2,sd2)
    value93=random.normal(m2,sd2)
    value94=random.normal(m2,sd2)
    value95=random.normal(m2,sd2)
    value96=random.normal(m2,sd2)
    value97=random.normal(m2,sd2)
    value98=random.normal(m2,sd2)
    value99=random.normal(m2,sd2)
    value100=random.normal(m2,sd2)

    
    timestep =[value1,value2,value3,value4,value5,value6,value7,value8,value9,value10,
               value11,value12,value13,value14,value15,value16,value17,value18,value19,value20,
               value21,value22,value23,value24,value25,value26,value27,value28,value29,value30,
               value31,value32,value33,value34,value35,value36,value37,value38,value39,value40,
               value41,value42,value43,value44,value45,value46,value47,value48,value49,value50,
               value51,value52,value53,value54,value55,value56,value57,value58,value59,value60,
               value61,value62,value63,value64,value65,value66,value67,value68,value69,value70,
               value71,value72,value73,value74,value75,value76,value77,value78,value79,value80,
               value81,value82,value83,value84,value85,value86,value87,value88,value89,value90,
               value91,value92,value93,value94,value95,value96,value97,value98,value99,value100
              ]
    
    
    
    densities = np.array([value1,value2,value3,value4,value5,value6,value7,value8,value9,value10,
               value11,value12,value13,value14,value15,value16,value17,value18,value19,value20,
               value21,value22,value23,value24,value25,value26,value27,value28,value29,value30,
               value31,value32,value33,value34,value35,value36,value37,value38,value39,value40,
               value41,value42,value43,value44,value45,value46,value47,value48,value49,value50,
               value51,value52,value53,value54,value55,value56,value57,value58,value59,value60,
               value61,value62,value63,value64,value65,value66,value67,value68,value69,value70,
               value71,value72,value73,value74,value75,value76,value77,value78,value79,value80,
               value81,value82,value83,value84,value85,value86,value87,value88,value89,value90,
               value91,value92,value93,value94,value95,value96,value97,value98,value99,value100
                         ])
    summ=sum(timestep)
    mean=np.mean(timestep)
    vari=np.var(timestep)
    stdv=np.std(timestep)
    
    CV=stdv/mean
    
    n_years= densities.size
    years=np.arange(n_years)
    Covariance = np.cov(densities,years)[0][1]
   
  
    
    
    rlist =[value1,value2,value3,value4,value5,value6,value7,value8,value9,value10,
            value11,value12,value13,value14,value15,value16,value17,value18,value19,value20,
            value21,value22,value23,value24,value25,value26,value27,value28,value29,value30,
            value31,value32,value33,value34,value35,value36,value37,value38,value39,value40,
            value41,value42,value43,value44,value45,value46,value47,value48,value49,value50,
            value51,value52,value53,value54,value55,value56,value57,value58,value59,value60,
            value61,value62,value63,value64,value65,value66,value67,value68,value69,value70,
            value71,value72,value73,value74,value75,value76,value77,value78,value79,value80,
            value81,value82,value83,value84,value85,value86,value87,value88,value89,value90,
            value91,value92,value93,value94,value95,value96,value97,value98,value99,value100
           ]
    rlist.sort()

    r1=rlist[0]
    r2=rlist[1]
    r3=rlist[2]
    r4=rlist[3]
    r5=rlist[4]
    r6=rlist[5]
    r7=rlist[6]
    r8=rlist[7]
    r9=rlist[8]
    r10=rlist[9]
    
    r11=rlist[10]
    r12=rlist[11]
    r13=rlist[12]
    r14=rlist[13]
    r15=rlist[14]
    r16=rlist[15]
    r17=rlist[16]
    r18=rlist[17]
    r19=rlist[18]
    r20=rlist[19]
    
    r21=rlist[20]
    r22=rlist[21]
    r23=rlist[22]
    r24=rlist[23]
    r25=rlist[24]
    r26=rlist[25]
    r27=rlist[26]
    r28=rlist[27]
    r29=rlist[28]
    r30=rlist[29]
    
    r31=rlist[30]
    r32=rlist[31]
    r33=rlist[32]
    r34=rlist[33]
    r35=rlist[34]
    r36=rlist[35]
    r37=rlist[36]
    r38=rlist[37]
    r39=rlist[38]
    r40=rlist[39]
    
    r41=rlist[40]
    r42=rlist[41]
    r43=rlist[42]
    r44=rlist[43]
    r45=rlist[44]
    r46=rlist[45]
    r47=rlist[46]
    r48=rlist[47]
    r49=rlist[48]
    r50=rlist[49]
    
    r51=rlist[50]
    r52=rlist[51]
    r53=rlist[52]
    r54=rlist[53]
    r55=rlist[54]
    r56=rlist[55]
    r57=rlist[56]
    r58=rlist[57]
    r59=rlist[58]
    r60=rlist[59]
    
    r61=rlist[60]
    r62=rlist[61]
    r63=rlist[62]
    r64=rlist[63]
    r65=rlist[64]
    r66=rlist[65]
    r67=rlist[66]
    r68=rlist[67]
    r69=rlist[68]
    r70=rlist[69]
    
    r71=rlist[70]
    r72=rlist[71]
    r73=rlist[72]
    r74=rlist[73]
    r75=rlist[74]
    r76=rlist[75]
    r77=rlist[76]
    r78=rlist[77]
    r79=rlist[78]
    r80=rlist[79]
    
    r81=rlist[80]
    r82=rlist[81]
    r83=rlist[82]
    r84=rlist[83]
    r85=rlist[84]
    r86=rlist[85]
    r87=rlist[86]
    r88=rlist[87]
    r89=rlist[88]
    r90=rlist[89]
    
    r91=rlist[90]
    r92=rlist[91]
    r93=rlist[92]
    r94=rlist[93]
    r95=rlist[94]
    r96=rlist[95]
    r97=rlist[96]
    r98=rlist[97]
    r99=rlist[98]
    r100=rlist[99]
    
    ###################################################################################
    #SDL
          
    lvalue1=round(np.log(value1),50)
    lvalue2=round(np.log(value2),50)
    lvalue3=round(np.log(value3),50)
    lvalue4=round(np.log(value4),50)
    lvalue5=round(np.log(value5),50)
    lvalue6=round(np.log(value6),50)
    lvalue7=round(np.log(value7),50)
    lvalue8=round(np.log(value8),50)
    lvalue9=round(np.log(value9),50)
    lvalue10=round(np.log(value10),50)
    lvalue11=round(np.log(value11),50)
    lvalue12=round(np.log(value12),50)
    lvalue13=round(np.log(value13),50)
    lvalue14=round(np.log(value14),50)
    lvalue15=round(np.log(value15),50)
    lvalue16=round(np.log(value16),50)
    lvalue17=round(np.log(value17),50)
    lvalue18=round(np.log(value18),50)
    lvalue19=round(np.log(value19),50)
    lvalue20=round(np.log(value20),50)
    lvalue21=round(np.log(value21),50)
    lvalue22=round(np.log(value22),50)
    lvalue23=round(np.log(value23),50)
    lvalue24=round(np.log(value24),50)
    lvalue25=round(np.log(value25),50)
    lvalue26=round(np.log(value26),50)
    lvalue27=round(np.log(value27),50)
    lvalue28=round(np.log(value28),50)
    lvalue29=round(np.log(value29),50)
    lvalue30=round(np.log(value30),50)
    lvalue31=round(np.log(value31),50)
    lvalue32=round(np.log(value32),50)
    lvalue33=round(np.log(value33),50)
    lvalue34=round(np.log(value34),50)
    lvalue35=round(np.log(value35),50)
    lvalue36=round(np.log(value36),50)
    lvalue37=round(np.log(value37),50)
    lvalue38=round(np.log(value38),50)
    lvalue39=round(np.log(value39),50)
    lvalue40=round(np.log(value40),50)
    lvalue41=round(np.log(value41),50)
    lvalue42=round(np.log(value42),50)
    lvalue43=round(np.log(value43),50)
    lvalue44=round(np.log(value44),50)
    lvalue45=round(np.log(value45),50)
    lvalue46=round(np.log(value46),50)
    lvalue47=round(np.log(value47),50)
    lvalue48=round(np.log(value48),50)
    lvalue49=round(np.log(value49),50)
    lvalue50=round(np.log(value50),50)
    lvalue51=round(np.log(value51),50)
    lvalue52=round(np.log(value52),50)
    lvalue53=round(np.log(value53),50)
    lvalue54=round(np.log(value54),50)
    lvalue55=round(np.log(value55),50)
    lvalue56=round(np.log(value56),50)
    lvalue57=round(np.log(value57),50)
    lvalue58=round(np.log(value58),50)
    lvalue59=round(np.log(value59),50)
    lvalue60=round(np.log(value60),50)
    lvalue61=round(np.log(value61),50)
    lvalue62=round(np.log(value62),50)
    lvalue63=round(np.log(value63),50)
    lvalue64=round(np.log(value64),50)
    lvalue65=round(np.log(value65),50)
    lvalue66=round(np.log(value66),50)
    lvalue67=round(np.log(value67),50)
    lvalue68=round(np.log(value68),50)
    lvalue69=round(np.log(value69),50)
    lvalue70=round(np.log(value70),50)
    lvalue71=round(np.log(value71),50)
    lvalue72=round(np.log(value72),50)
    lvalue73=round(np.log(value73),50)
    lvalue74=round(np.log(value74),50)
    lvalue75=round(np.log(value75),50)
    lvalue76=round(np.log(value76),50)
    lvalue77=round(np.log(value77),50)
    lvalue78=round(np.log(value78),50)
    lvalue79=round(np.log(value79),50)
    lvalue80=round(np.log(value80),50)
    lvalue81=round(np.log(value81),50)
    lvalue82=round(np.log(value82),50)
    lvalue83=round(np.log(value83),50)
    lvalue84=round(np.log(value84),50)
    lvalue85=round(np.log(value85),50)
    lvalue86=round(np.log(value86),50)
    lvalue87=round(np.log(value87),50)
    lvalue88=round(np.log(value88),50)
    lvalue89=round(np.log(value89),50)
    lvalue90=round(np.log(value90),50)
    lvalue91=round(np.log(value91),50)
    lvalue92=round(np.log(value92),50)
    lvalue93=round(np.log(value93),50)
    lvalue94=round(np.log(value94),50)
    lvalue95=round(np.log(value95),50)
    lvalue96=round(np.log(value96),50)
    lvalue97=round(np.log(value97),50)
    lvalue98=round(np.log(value98),50)
    lvalue99=round(np.log(value99),50)
    lvalue100=round(np.log(value100),50)
    
    
    lwlist =[lvalue1,lvalue2,lvalue3,lvalue4,lvalue5,lvalue6,lvalue7,lvalue8,lvalue9,lvalue10,
             lvalue11,lvalue12,lvalue13,lvalue14,lvalue15,lvalue16,lvalue17,lvalue18,lvalue19,lvalue20,
             lvalue21,lvalue22,lvalue23,lvalue24,lvalue25,lvalue26,lvalue27,lvalue28,lvalue29,lvalue30,
             lvalue31,lvalue32,lvalue33,lvalue34,lvalue35,lvalue36,lvalue37,lvalue38,lvalue39,lvalue40,
             lvalue41,lvalue42,lvalue43,lvalue44,lvalue45,lvalue46,lvalue47,lvalue48,lvalue49,lvalue50,
             lvalue51,lvalue52,lvalue53,lvalue54,lvalue55,lvalue56,lvalue57,lvalue58,lvalue59,lvalue60,
             lvalue61,lvalue62,lvalue63,lvalue64,lvalue65,lvalue66,lvalue67,lvalue68,lvalue69,lvalue70,
             lvalue71,lvalue72,lvalue73,lvalue74,lvalue75,lvalue76,lvalue77,lvalue78,lvalue79,lvalue80,
             lvalue81,lvalue82,lvalue83,lvalue84,lvalue85,lvalue86,lvalue87,lvalue88,lvalue89,lvalue90,
             lvalue91,lvalue92,lvalue93,lvalue94,lvalue95,lvalue96,lvalue97,lvalue98,lvalue99,lvalue100
            ]
    lwlist.sort() 
    
   
    SDL=np.std(lwlist) 
   
   
    
    ##########################################################################################
    #PV_S
   
    abover1=np.sum(rlist[1:100])
    abover2=np.sum(rlist[2:100])
    abover3=np.sum(rlist[3:100])
    abover4=np.sum(rlist[4:100])
    abover5=np.sum(rlist[5:100])
    abover6=np.sum(rlist[6:100])       
    abover7=np.sum(rlist[7:100])
    abover8=np.sum(rlist[8:100])
    abover9=np.sum(rlist[9:100])
    abover10=np.sum(rlist[10:100])
    abover11=np.sum(rlist[11:100])
    abover12=np.sum(rlist[12:100])
    abover13=np.sum(rlist[13:100])
    abover14=np.sum(rlist[14:100])
    abover15=np.sum(rlist[15:100])
    abover16=np.sum(rlist[16:100])             
    abover17=np.sum(rlist[17:100])     
    abover18=np.sum(rlist[18:100])     
    abover19=np.sum(rlist[19:100])    
    abover20=np.sum(rlist[20:100])    
    abover21=np.sum(rlist[21:100])                 
    abover22=np.sum(rlist[22:100])     
    abover23=np.sum(rlist[23:100]) 
    abover24=np.sum(rlist[24:100])
    abover25=np.sum(rlist[25:100])    
    abover26=np.sum(rlist[26:100])         
    abover27=np.sum(rlist[27:100]) 
    abover28=np.sum(rlist[28:100])       
    abover29=np.sum(rlist[29:100])     
    abover30=np.sum(rlist[30:100]) 
    abover31=np.sum(rlist[31:100])                
    abover32=np.sum(rlist[32:100])  
    abover33=np.sum(rlist[33:100])
    abover34=np.sum(rlist[34:100])    
    abover35=np.sum(rlist[35:100])    
    abover36=np.sum(rlist[36:100])         
    abover37=np.sum(rlist[37:100]) 
    abover38=np.sum(rlist[38:100])       
    abover39=np.sum(rlist[39:100])     
    abover40=np.sum(rlist[40:100]) 
    abover41=np.sum(rlist[41:100])                
    abover42=np.sum(rlist[42:100])  
    abover43=np.sum(rlist[43:100])
    abover44=np.sum(rlist[44:100])  
    abover45=np.sum(rlist[45:100]) 
    abover46=np.sum(rlist[46:100])                
    abover47=np.sum(rlist[47:100])  
    abover48=np.sum(rlist[48:100])
    abover49=np.sum(rlist[49:100]) 
    abover50=np.sum(rlist[50:100]) 
    abover51=np.sum(rlist[51:100])                
    abover52=np.sum(rlist[52:100])  
    abover53=np.sum(rlist[53:100])
    abover54=np.sum(rlist[54:100])    
    abover55=np.sum(rlist[55:100])    
    abover56=np.sum(rlist[56:100])         
    abover57=np.sum(rlist[57:100]) 
    abover58=np.sum(rlist[58:100])       
    abover59=np.sum(rlist[59:100])     
    abover60=np.sum(rlist[60:100]) 
    abover61=np.sum(rlist[61:100])                
    abover62=np.sum(rlist[62:100])  
    abover63=np.sum(rlist[63:100])
    abover64=np.sum(rlist[64:100])  
    abover65=np.sum(rlist[65:100]) 
    abover66=np.sum(rlist[66:100])                
    abover67=np.sum(rlist[67:100])  
    abover68=np.sum(rlist[68:100])
    abover69=np.sum(rlist[69:100])   
    abover70=np.sum(rlist[70:100]) 
    abover71=np.sum(rlist[71:100])                
    abover72=np.sum(rlist[72:100])  
    abover73=np.sum(rlist[73:100])
    abover74=np.sum(rlist[74:100])  
    abover75=np.sum(rlist[75:100]) 
    abover76=np.sum(rlist[76:100])                
    abover77=np.sum(rlist[77:100])  
    abover78=np.sum(rlist[78:100])
    abover79=np.sum(rlist[79:100]) 
    abover80=np.sum(rlist[80:100]) 
    abover81=np.sum(rlist[81:100])                
    abover82=np.sum(rlist[82:100])  
    abover83=np.sum(rlist[83:100])
    abover84=np.sum(rlist[84:100])    
    abover85=np.sum(rlist[85:100])    
    abover86=np.sum(rlist[86:100])         
    abover87=np.sum(rlist[87:100]) 
    abover88=np.sum(rlist[88:100])       
    abover89=np.sum(rlist[89:100])     
    abover90=np.sum(rlist[90:100]) 
    abover91=np.sum(rlist[91:100])                
    abover92=np.sum(rlist[92:100])  
    abover93=np.sum(rlist[93:100])
    abover94=np.sum(rlist[94:100])  
    abover95=np.sum(rlist[95:100]) 
    abover96=np.sum(rlist[96:100])                
    abover97=np.sum(rlist[97:100])  
    abover98=np.sum(rlist[98:100])
    abover99=np.sum(rlist[99:100])   
                                                  
    Supra1=abover1/r1
    Supra2=abover2/r2
    Supra3=abover3/r3
    Supra4=abover4/r4
    Supra5=abover5/r5
    Supra6=abover6/r6
    Supra7=abover7/r7
    Supra8=abover8/r8
    Supra9=abover9/r9
    Supra10=abover10/r10
    Supra11=abover11/r11
    Supra12=abover12/r12
    Supra13=abover13/r13
    Supra14=abover14/r14
    Supra15=abover15/r15
    Supra16=abover16/r16
    Supra17=abover17/r17
    Supra18=abover18/r18
    Supra19=abover19/r19
    Supra20=abover20/r20                 
    Supra21=abover21/r21
    Supra22=abover22/r22
    Supra23=abover23/r23
    Supra24=abover24/r24
    Supra25=abover25/r25
    Supra26=abover26/r26
    Supra27=abover27/r27
    Supra28=abover28/r28
    Supra29=abover29/r29
    Supra30=abover30/r30   
    Supra31=abover31/r31
    Supra32=abover32/r32
    Supra33=abover33/r33
    Supra34=abover34/r34
    Supra35=abover35/r35
    Supra36=abover36/r36
    Supra37=abover37/r37
    Supra38=abover38/r38
    Supra39=abover39/r39
    Supra40=abover40/r40   
    Supra41=abover41/r41
    Supra42=abover42/r42
    Supra43=abover43/r43
    Supra44=abover44/r44 
    Supra45=abover45/r45   
    Supra46=abover46/r46
    Supra47=abover47/r47
    Supra48=abover48/r48
    Supra49=abover49/r49 
    Supra50=abover50/r50   
    Supra51=abover51/r51
    Supra52=abover52/r52
    Supra53=abover53/r53
    Supra54=abover54/r54
    Supra55=abover55/r55
    Supra56=abover56/r56
    Supra57=abover57/r57
    Supra58=abover58/r58
    Supra59=abover59/r59
    Supra60=abover60/r60   
    Supra61=abover61/r61
    Supra62=abover62/r62
    Supra63=abover63/r63
    Supra64=abover64/r64 
    Supra65=abover65/r65   
    Supra66=abover66/r66
    Supra67=abover67/r67
    Supra68=abover68/r68
    Supra69=abover69/r69

    Supra70=abover70/r70   
    Supra71=abover71/r71
    Supra72=abover72/r72
    Supra73=abover73/r73
    Supra74=abover74/r74 
    Supra75=abover75/r75   
    Supra76=abover76/r76
    Supra77=abover77/r77
    Supra78=abover78/r78
    Supra79=abover79/r79 
    Supra80=abover80/r80   
    Supra81=abover81/r81
    Supra82=abover82/r82
    Supra83=abover83/r83
    Supra84=abover84/r84
    Supra85=abover85/r85
    Supra86=abover86/r86
    Supra87=abover87/r87
    Supra88=abover88/r88
    Supra89=abover89/r89
    Supra90=abover90/r90   
    Supra91=abover91/r91
    Supra92=abover92/r92
    Supra93=abover93/r93
    Supra94=abover94/r94 
    Supra95=abover95/r95   
    Supra96=abover96/r96
    Supra97=abover97/r97
    Supra98=abover98/r98
    Supra99=abover99/r99

    
    SupraSum=(
             )-4950

    
    
    #######################################################################################
    #######################################################################################
    #PV_I

    belowr100=np.sum(rlist[0:99])
    belowr99=np.sum(rlist[0:98])
    belowr98=np.sum(rlist[0:97])
    belowr97=np.sum(rlist[0:96])
    belowr96=np.sum(rlist[0:95])
    belowr95=np.sum(rlist[0:94])
    belowr94=np.sum(rlist[0:93])
    belowr93=np.sum(rlist[0:92])
    belowr92=np.sum(rlist[0:91])
    belowr91=np.sum(rlist[0:90])
    belowr90=np.sum(rlist[0:89])
    belowr89=np.sum(rlist[0:88])
    belowr88=np.sum(rlist[0:87])
    belowr87=np.sum(rlist[0:86])
    belowr86=np.sum(rlist[0:85])
    belowr85=np.sum(rlist[0:84])
    belowr84=np.sum(rlist[0:83])
    belowr83=np.sum(rlist[0:82])
    belowr82=np.sum(rlist[0:81])
    belowr81=np.sum(rlist[0:80])
    belowr80=np.sum(rlist[0:79])
    belowr79=np.sum(rlist[0:78])
    belowr78=np.sum(rlist[0:77])
    belowr77=np.sum(rlist[0:76])
    belowr76=np.sum(rlist[0:75])
    belowr75=np.sum(rlist[0:74])
    belowr74=np.sum(rlist[0:73])
    belowr73=np.sum(rlist[0:72])
    belowr72=np.sum(rlist[0:71])
    belowr71=np.sum(rlist[0:70])
    belowr70=np.sum(rlist[0:69])
    belowr69=np.sum(rlist[0:68])
    belowr68=np.sum(rlist[0:67])
    belowr67=np.sum(rlist[0:66])
    belowr66=np.sum(rlist[0:65])
    belowr65=np.sum(rlist[0:64])
    belowr64=np.sum(rlist[0:63])
    belowr63=np.sum(rlist[0:62])
    belowr62=np.sum(rlist[0:61])
    belowr61=np.sum(rlist[0:60])
    belowr60=np.sum(rlist[0:59])
    belowr59=np.sum(rlist[0:58])
    belowr58=np.sum(rlist[0:57])
    belowr57=np.sum(rlist[0:56])
    belowr56=np.sum(rlist[0:55])
    belowr55=np.sum(rlist[0:54])
    belowr54=np.sum(rlist[0:53])
    belowr53=np.sum(rlist[0:52])
    belowr52=np.sum(rlist[0:51])
    belowr51=np.sum(rlist[0:50])
    belowr50=np.sum(rlist[0:49])
    belowr49=np.sum(rlist[0:48])
    belowr48=np.sum(rlist[0:47])
    belowr47=np.sum(rlist[0:46])
    belowr46=np.sum(rlist[0:45])
    belowr45=np.sum(rlist[0:44])
    belowr44=np.sum(rlist[0:43])
    belowr43=np.sum(rlist[0:42])
    belowr42=np.sum(rlist[0:41])
    belowr41=np.sum(rlist[0:40])
    belowr40=np.sum(rlist[0:39])
    belowr39=np.sum(rlist[0:38])
    belowr38=np.sum(rlist[0:37])
    belowr37=np.sum(rlist[0:36])
    belowr36=np.sum(rlist[0:35])
    belowr35=np.sum(rlist[0:34])
    belowr34=np.sum(rlist[0:33])
    belowr33=np.sum(rlist[0:32])
    belowr32=np.sum(rlist[0:31])
    belowr31=np.sum(rlist[0:30])
    belowr30=np.sum(rlist[0:29])
    belowr29=np.sum(rlist[0:28])
    belowr28=np.sum(rlist[0:27])
    belowr27=np.sum(rlist[0:26])
    belowr26=np.sum(rlist[0:25])
    belowr25=np.sum(rlist[0:24])
    belowr24=np.sum(rlist[0:23])
    belowr23=np.sum(rlist[0:22])
    belowr22=np.sum(rlist[0:21])
    belowr21=np.sum(rlist[0:20])
    belowr20=np.sum(rlist[0:19])
    belowr19=np.sum(rlist[0:18])
    belowr18=np.sum(rlist[0:17])
    belowr17=np.sum(rlist[0:16])
    belowr16=np.sum(rlist[0:15])
    belowr15=np.sum(rlist[0:14])
    belowr14=np.sum(rlist[0:13])
    belowr13=np.sum(rlist[0:12])
    belowr12=np.sum(rlist[0:11])
    belowr11=np.sum(rlist[0:10])
    belowr10=np.sum(rlist[0:9])
    belowr9=np.sum(rlist[0:8])
    belowr8=np.sum(rlist[0:7])
    belowr7=np.sum(rlist[0:6])
    belowr6=np.sum(rlist[0:5])
    belowr5=np.sum(rlist[0:4])
    belowr4=np.sum(rlist[0:3])
    belowr3=np.sum(rlist[0:2])
    belowr2=np.sum(rlist[0:1])
    
    
    
    Infra100=belowr100/r100
    Infra99=belowr99/r99
    Infra98=belowr98/r98
    Infra97=belowr97/r97
    Infra96=belowr96/r96
    Infra95=belowr95/r95
    Infra94=belowr94/r94
    Infra93=belowr93/r93
    Infra92=belowr92/r92
    Infra91=belowr91/r91
    Infra90=belowr90/r90
    Infra89=belowr89/r89
    Infra88=belowr88/r88
    Infra87=belowr87/r87
    Infra86=belowr86/r86
    Infra85=belowr85/r85
    Infra84=belowr84/r84
    Infra83=belowr83/r83
    Infra82=belowr82/r82
    Infra81=belowr81/r81
    Infra80=belowr80/r80
    Infra79=belowr79/r79
    Infra78=belowr78/r78
    Infra77=belowr77/r77
    Infra76=belowr76/r76
    Infra75=belowr75/r75
    Infra74=belowr74/r74
    Infra73=belowr73/r73
    Infra72=belowr72/r72
    Infra71=belowr71/r71
    Infra70=belowr70/r70
    Infra69=belowr69/r69
    Infra68=belowr68/r68
    Infra67=belowr67/r67
    Infra66=belowr66/r66
    Infra65=belowr65/r65
    Infra64=belowr64/r64
    Infra63=belowr63/r63
    Infra62=belowr62/r62
    Infra61=belowr61/r61
    Infra60=belowr60/r60
    Infra59=belowr59/r59
    Infra58=belowr58/r58
    Infra57=belowr57/r57
    Infra56=belowr56/r56
    Infra55=belowr55/r55
    Infra54=belowr54/r54
    Infra53=belowr53/r53
    Infra52=belowr52/r52
    Infra51=belowr51/r51
    Infra50=belowr50/r50
    Infra49=belowr49/r49
    Infra48=belowr48/r48
    Infra47=belowr47/r47
    Infra46=belowr46/r46
    Infra45=belowr45/r45
    Infra44=belowr44/r44
    Infra43=belowr43/r43
    Infra42=belowr42/r42
    Infra41=belowr41/r41
    Infra40=belowr40/r40
    Infra39=belowr39/r39
    Infra38=belowr38/r38
    Infra37=belowr37/r37
    Infra36=belowr36/r36
    Infra35=belowr35/r35
    Infra34=belowr34/r34
    Infra33=belowr33/r33
    Infra32=belowr32/r32
    Infra31=belowr31/r31
    Infra30=belowr30/r30
    Infra29=belowr29/r29
    Infra28=belowr28/r28
    Infra27=belowr27/r27
    Infra26=belowr26/r26
    Infra25=belowr25/r25
    Infra24=belowr24/r24
    Infra23=belowr23/r23
    Infra22=belowr22/r22
    Infra21=belowr21/r21
    Infra20=belowr20/r20
    Infra19=belowr19/r19
    Infra18=belowr18/r18
    Infra17=belowr17/r17
    Infra16=belowr16/r16
    Infra15=belowr15/r15
    Infra14=belowr14/r14
    Infra13=belowr13/r13
    Infra12=belowr12/r12
    Infra11=belowr11/r11
    Infra10=belowr10/r10
    Infra9=belowr9/r9
    Infra8=belowr8/r8
    Infra7=belowr7/r7
    Infra6=belowr6/r6
    Infra5=belowr5/r5
    Infra4=belowr4/r4
    Infra3=belowr3/r3
    Infra2=belowr2/r2
    
    InfraSum=4950-(
                  )
    
  

    MPV_S=SupraSum/5000
    PV_S=1-(1/(1+MPV_S))
    
    PV_I=InfraSum/5000
    Heath=InfraSum/4950
  
    MPV_D=(SupraSum-InfraSum)/5000
    PV_D=1-(1/(1+MPV_D))
    
    MPV=(InfraSum+SupraSum)/10000
    PV=1-(1/(1+MPV))
   
    ##############################################################################################
    ##############################################################################
    #Average deviation from the mean
    
    md1=abs(value1-mean)
    md2=abs(value2-mean)
    md3=abs(value3-mean)
    md4=abs(value4-mean)
    md5=abs(value5-mean)
    md6=abs(value6-mean)
    md7=abs(value7-mean)
    md8=abs(value8-mean)
    md9=abs(value9-mean)
    md10=abs(value10-mean)
    
    md11=abs(value11-mean)
    md12=abs(value12-mean)
    md13=abs(value13-mean)
    md14=abs(value14-mean)
    md15=abs(value15-mean)
    md16=abs(value16-mean)
    md17=abs(value17-mean)
    md18=abs(value18-mean)
    md19=abs(value19-mean)
    md20=abs(value20-mean)
    
    md21=abs(value21-mean)
    md22=abs(value22-mean)
    md23=abs(value23-mean)
    md24=abs(value24-mean)
    md25=abs(value25-mean)
    md26=abs(value26-mean)
    md27=abs(value27-mean)
    md28=abs(value28-mean)
    md29=abs(value29-mean)
    md30=abs(value30-mean)
    
    md31=abs(value31-mean)
    md32=abs(value32-mean)
    md33=abs(value33-mean)
    md34=abs(value34-mean)
    md35=abs(value35-mean)
    md36=abs(value36-mean)
    md37=abs(value37-mean)
    md38=abs(value38-mean)
    md39=abs(value39-mean)
    md40=abs(value40-mean)
    
    md41=abs(value41-mean)
    md42=abs(value42-mean)
    md43=abs(value43-mean)
    md44=abs(value44-mean)
    md45=abs(value45-mean)
    md46=abs(value46-mean)
    md47=abs(value47-mean)
    md48=abs(value48-mean)
    md49=abs(value49-mean)
    md50=abs(value50-mean)
    
    md51=abs(value51-mean)
    md52=abs(value52-mean)
    md53=abs(value53-mean)
    md54=abs(value54-mean)
    md55=abs(value55-mean)
    md56=abs(value56-mean)
    md57=abs(value57-mean)
    md58=abs(value58-mean)
    md59=abs(value59-mean)
    md60=abs(value60-mean)
    
    md61=abs(value61-mean)
    md62=abs(value62-mean)
    md63=abs(value63-mean)
    md64=abs(value64-mean)
    md65=abs(value65-mean)
    md66=abs(value66-mean)
    md67=abs(value67-mean)
    md68=abs(value68-mean)
    md69=abs(value69-mean)
    md70=abs(value70-mean)
    
    md71=abs(value71-mean)
    md72=abs(value72-mean)
    md73=abs(value73-mean)
    md74=abs(value74-mean)
    md75=abs(value75-mean)
    md76=abs(value76-mean)
    md77=abs(value77-mean)
    md78=abs(value78-mean)
    md79=abs(value79-mean)
    md80=abs(value80-mean)
    
    md81=abs(value81-mean)
    md82=abs(value82-mean)
    md83=abs(value83-mean)
    md84=abs(value84-mean)
    md85=abs(value85-mean)
    md86=abs(value86-mean)
    md87=abs(value87-mean)
    md88=abs(value88-mean)
    md89=abs(value89-mean)
    md90=abs(value90-mean)
    
    md91=abs(value91-mean)
    md92=abs(value92-mean)
    md93=abs(value93-mean)
    md94=abs(value94-mean)
    md95=abs(value95-mean)
    md96=abs(value96-mean)
    md97=abs(value97-mean)
    md98=abs(value98-mean)
    md99=abs(value99-mean)
    md100=abs(value100-mean)
    
    ADM=( 
         md81+md82+md83+md84+md85+md86+md87+md88+md89+md90+md91+md92+md93+md94+md95+md96+md97+md98+md99+md100
        )/100
    
   
    #################################################################################
    i+=1 
    
    dataframe2.loc[len(dataframe2)] = (MPV_S,MPV_D,MPV,
                                       PV_S,PV_I,PV_D,PV,
                                       Heath,CV,SDL,ADM,mean,
                                       value1,value2,value3,value4,value5,
                                       value6,value7,value8,value9,value10,
                                       value11,value12,value13,value14,value15,
                                       value16,value17,value18,value19,value20,
                                       value21,value22,value23,value24,value25,
                                       value26,value27,value28,value29,value30,
                                       value31,value32,value33,value34,value35,
                                       value36,value37,value38,value39,value40,
                                       value41,value42,value43,value44,value45,
                                       value46,value47,value48,value49,value50,
                                       value51,value52,value53,value54,value55,
                                       value56,value57,value58,value59,value60,
                                       value61,value62,value63,value64,value65,
                                       value66,value67,value68,value69,value70,
                                       value71,value72,value73,value74,value75,
                                       value76,value77,value78,value79,value80,
                                       value81,value82,value83,value84,value85,
                                       value86,value87,value88,value89,value90,
                                       value91,value92,value93,value94,value95,
                                       value96,value97,value98,value99,value100
                                      )

# %%
dataframe2
# Out:
#           MPV_S     MPV_D       MPV      PV_S      PV_I      PV_D        PV  \
# 0      4.674116  4.164860  2.591686  0.823761  0.509256  0.806384  0.721579
# 1      4.534358  4.033745  2.517485  0.819311  0.500613  0.801341  0.715706
# 2      4.555903  4.053867  2.528969  0.820011  0.502036  0.802132  0.716631
# 3      4.554079  4.051911  2.528124  0.819952  0.502168  0.802055  0.716563
# 4      4.497011  4.005524  2.494249  0.818083  0.491486  0.800221  0.713815
# ...         ...       ...       ...       ...       ...       ...       ...
# 9996   4.563519  4.059972  2.533533  0.820258  0.503547  0.802370  0.716997
# 9997   4.610363  4.109893  2.555417  0.821758  0.500470  0.804301  0.718739
# 9998   4.578419  4.076726  2.540056  0.820738  0.501694  0.803023  0.717519
# 9999   4.587779  4.084675  2.545442  0.821038  0.503104  0.803331  0.717948
# 10000  4.540900  4.037088  2.522356  0.819524  0.503812  0.801473  0.716099
#
# ...

# %%
#dataframe2.to_excel(r'C:/Documents/Pandas2Excel/N100_ProportionalVariabilities_SDL_CV_BimodalCondition.xlsx', sheet_name='Sheet1', index = True)
