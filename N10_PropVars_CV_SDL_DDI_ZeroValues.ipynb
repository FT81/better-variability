# %%
import numpy as np
from numpy import random
import pandas as pd
import math
import statistics as stats

# %%
df = pd.DataFrame(columns=['CV','SDL','Infra','DDI','Supra','Delta','PV',
                           'percent1','percent2','percent3','percent4','percent5',
                           'percent6','percent7','percent8','percent9','percent10',
                           'value1','value2','value3','value4','value5','value6','value7','value8','value9','value10'
                           ])

# %%
i=0
while i <=10000:

    Value1=0
    Value2=np.random.randint(0,3)
    Value3=np.random.randint(0,3)
    Value4=np.random.randint(0,4)
    Value5=np.random.randint(0,5)
    Value6=np.random.randint(0,6)
    Value7=np.random.randint(0,7)
    Value8=np.random.randint(0,8)
    Value9=np.random.randint(0,9)
    Value10=np.random.randint(1,11)
    
    
    vlist =[Value1,Value2,Value3,Value4,Value5,Value6,Value7,Value8,Value9,Value10]
    vlist.sort()
 
    x1=vlist[0]
    x2=vlist[1]
    x3=vlist[2]
    x4=vlist[3]
    x5=vlist[4]
    x6=vlist[5]
    x7=vlist[6]
    x8=vlist[7]
    x9=vlist[8]
    x10=vlist[9]
    
    
    
    Value1tf=vlist[0]
    Value2tf=vlist[1]
    Value3tf=vlist[2]
    Value4tf=vlist[3]
    Value5tf=vlist[4]
    Value6tf=vlist[5]
    Value7tf=vlist[6]
    Value8tf=vlist[7]
    Value9tf=vlist[8]
    Value10tf=vlist[9] 
    
    lValue1=round(np.log(Value1+1),20)
    lValue2=round(np.log(Value2+1),20)
    lValue3=round(np.log(Value3+1),20)
    lValue4=round(np.log(Value4+1),20)
    lValue5=round(np.log(Value5+1),20)
    lValue6=round(np.log(Value6+1),20)
    lValue7=round(np.log(Value7+1),20)
    lValue8=round(np.log(Value8+1),20)
    lValue9=round(np.log(Value9+1),20)
    lValue10=round(np.log(Value10+1),20)

    lvlist =[lValue1,lValue2,lValue3,lValue4,lValue5,lValue6,lValue7,lValue8,lValue9,lValue10]
    lvlist.sort() 
    
    SDL=np.std(lvlist)
    Summ=np.sum(vlist)
    mean=np.mean(vlist)
    stdv=np.std(vlist)
    Vari=np.var(vlist)
    CV=stdv/mean
   
 
    constant=np.random.choice([math.e/2,math.e/2])
    alpha4DDI=1
    
    ##############################################################################################
    #PV_I
    
    
    if(x1>0):
        Infra12=abs(x1-x2)/max(x1,x2)
        Infra13=abs(x1-x3)/max(x1,x3)
        Infra14=abs(x1-x4)/max(x1,x4)
        Infra15=abs(x1-x5)/max(x1,x5)
        Infra16=abs(x1-x6)/max(x1,x6)
        Infra17=abs(x1-x7)/max(x1,x7)
        Infra18=abs(x1-x8)/max(x1,x8)
        Infra19=abs(x1-x9)/max(x1,x9)
        Infra110=abs(x1-x10)/max(x1,x10)
        
    if(x1==0 and x2==0):
        Infra12=0
    if(x1==0 and x2>0):
        Infra12=1    
    if(x1==0 and x3==0):
        Infra13=0
    if(x1==0 and x3>0):
        Infra13=1  
    if(x1==0 and x4==0):
        Infra14=0
    if(x1==0 and x4>0):
        Infra14=1 
    if(x1==0 and x5==0):
        Infra15=0
    if(x1==0 and x5>0):
        Infra15=1    
    if(x1==0 and x6==0):
        Infra16=0
    if(x1==0 and x6>0):
        Infra16=1    
    if(x1==0 and x7==0):
        Infra17=0
    if(x1==0 and x7>0):
        Infra17=1  
    if(x1==0 and x8==0):
        Infra18=0
    if(x1==0 and x8>0):
        Infra18=1 
    if(x1==0 and x9==0):
        Infra19=0
    if(x1==0 and x9>0):
        Infra19=1   
    if(x1==0 and x10==0):
        Infra110=0
    if(x1==0 and x10>0):
        Infra110=1      
    
    
    if(x2>0):
        Infra23=abs(x2-x3)/max(x2,x3)
        Infra24=abs(x2-x4)/max(x2,x4)
        Infra25=abs(x2-x5)/max(x2,x5)
        Infra26=abs(x2-x6)/max(x2,x6)
        Infra27=abs(x2-x7)/max(x2,x7)
        Infra28=abs(x2-x8)/max(x2,x8)
        Infra29=abs(x2-x9)/max(x2,x9)
        Infra210=abs(x2-x10)/max(x2,x10)

    if(x2==0 and x3==0):
        Infra23=0
    if(x2==0 and x3>0):
        Infra23=1  
    if(x2==0 and x4==0):
        Infra24=0
    if(x2==0 and x4>0):
        Infra24=1 
    if(x2==0 and x5==0):
        Infra25=0
    if(x2==0 and x5>0):
        Infra25=1    
    if(x2==0 and x6==0):
        Infra26=0
    if(x2==0 and x6>0):
        Infra26=1    
    if(x2==0 and x7==0):
        Infra27=0
    if(x2==0 and x7>0):
        Infra27=1  
    if(x2==0 and x8==0):
        Infra28=0
    if(x2==0 and x8>0):
        Infra28=1 
    if(x2==0 and x9==0):
        Infra29=0
    if(x2==0 and x9>0):
        Infra29=1   
    if(x2==0 and x10==0):
        Infra210=0
    if(x1==0 and x10>0):
        Infra210=1      
    
    
    
    if(x3>0):
        Infra34=abs(x3-x4)/max(x3,x4)
        Infra35=abs(x3-x5)/max(x3,x5)
        Infra36=abs(x3-x6)/max(x3,x6)
        Infra37=abs(x3-x7)/max(x3,x7)
        Infra38=abs(x3-x8)/max(x3,x8)
        Infra39=abs(x3-x9)/max(x3,x9)
        Infra310=abs(x3-x10)/max(x3,x10)

    if(x3==0 and x4==0):
        Infra34=0
    if(x3==0 and x4>0):
        Infra34=1 
    if(x3==0 and x5==0):
        Infra35=0
    if(x3==0 and x5>0):
        Infra35=1    
    if(x3==0 and x6==0):
        Infra36=0
    if(x3==0 and x6>0):
        Infra36=1    
    if(x3==0 and x7==0):
        Infra37=0
    if(x3==0 and x7>0):
        Infra37=1  
    if(x3==0 and x8==0):
        Infra38=0
    if(x3==0 and x8>0):
        Infra38=1 
    if(x3==0 and x9==0):
        Infra39=0
    if(x3==0 and x9>0):
        Infra39=1   
    if(x3==0 and x10==0):
        Infra310=0
    if(x3==0 and x10>0):
        Infra310=1      
    
    
    if(x4>0):
        Infra45=abs(x4-x5)/max(x4,x5)
        Infra46=abs(x4-x6)/max(x4,x6)
        Infra47=abs(x4-x7)/max(x4,x7)
        Infra48=abs(x4-x8)/max(x4,x8)
        Infra49=abs(x4-x9)/max(x4,x9)
        Infra410=abs(x4-x10)/max(x4,x10)

    if(x4==0 and x5==0):
        Infra45=0
    if(x4==0 and x5>0):
        Infra45=1    
    if(x4==0 and x6==0):
        Infra46=0
    if(x4==0 and x6>0):
        Infra46=1    
    if(x4==0 and x7==0):
        Infra47=0
    if(x4==0 and x7>0):
        Infra47=1  
    if(x4==0 and x8==0):
        Infra48=0
    if(x4==0 and x8>0):
        Infra48=1 
    if(x4==0 and x9==0):
        Infra49=0
    if(x4==0 and x9>0):
        Infra49=1   
    if(x4==0 and x10==0):
        Infra410=0
    if(x4==0 and x10>0):
        Infra410=1      
    
    
        
    if(x5>0):
        Infra56=abs(x5-x6)/max(x5,x6)
        Infra57=abs(x5-x7)/max(x5,x7)
        Infra58=abs(x5-x8)/max(x5,x8)
        Infra59=abs(x5-x9)/max(x5,x9)
        Infra510=abs(x5-x10)/max(x5,x10)

    if(x5==0 and x6==0):
        Infra56=0
    if(x5==0 and x6>0):
        Infra56=1    
    if(x5==0 and x7==0):
        Infra57=0
    if(x5==0 and x7>0):
        Infra57=1  
    if(x5==0 and x8==0):
        Infra58=0
    if(x5==0 and x8>0):
        Infra58=1 
    if(x5==0 and x9==0):
        Infra59=0
    if(x5==0 and x9>0):
        Infra59=1   
    if(x5==0 and x10==0):
        Infra510=0
    if(x5==0 and x10>0):
        Infra510=1      
        
    if(x6>0):
        Infra67=abs(x6-x7)/max(x6,x7)
        Infra68=abs(x6-x8)/max(x6,x8)
        Infra69=abs(x6-x9)/max(x6,x9)
        Infra610=abs(x6-x10)/max(x6,x10)

    if(x6==0 and x7==0):
        Infra67=0
    if(x6==0 and x7>0):
        Infra67=1  
    if(x6==0 and x8==0):
        Infra68=0
    if(x6==0 and x8>0):
        Infra68=1 
    if(x6==0 and x9==0):
        Infra69=0
    if(x6==0 and x9>0):
        Infra69=1   
    if(x6==0 and x10==0):
        Infra610=0
    if(x6==0 and x10>0):
        Infra610=1      
        
          
    if(x7>0):
        Infra78=abs(x7-x8)/max(x7,x8)
        Infra79=abs(x7-x9)/max(x7,x9)
        Infra710=abs(x7-x10)/max(x7,x10)

    if(x7==0 and x8==0):
        Infra78=0
    if(x7==0 and x8>0):
        Infra78=1 
    if(x7==0 and x9==0):
        Infra79=0
    if(x7==0 and x9>0):
        Infra79=1   
    if(x7==0 and x10==0):
        Infra710=0
    if(x7==0 and x10>0):
        Infra710=1       
        
    if(x8>0):
        Infra89=abs(x8-x9)/max(x8,x9)
        Infra810=abs(x8-x10)/max(x8,x10)

    if(x8==0 and x9==0):
        Infra89=0
    if(x8==0 and x9>0):
        Infra89=1   
    if(x8==0 and x10==0):
        Infra810=0
    if(x8==0 and x10>0):
        Infra810=1         
        
    if(x9>0):
        Infra910=abs(x9-x10)/max(x9,x10)
        
    if(x9==0 and x10==0):
        Infra910=0
    if(x9==0 and x10>0):
        Infra910=1     
    
        
    SumInfra=(Infra12+Infra13+Infra14+Infra15+Infra16+Infra17+Infra18+Infra19+Infra110+
              Infra23+Infra24+Infra25+Infra26+Infra27+Infra28+Infra29+Infra210+
              Infra34+Infra35+Infra36+Infra37+Infra38+Infra39+Infra310+
              Infra45+Infra46+Infra47+Infra48+Infra49+Infra410+
              Infra56+Infra57+Infra58+Infra59+Infra510+
              Infra67+Infra68+Infra69+Infra610+
              Infra78+Infra79+Infra710+
              Infra89+Infra810+
              Infra910)
    
    
    Infra= SumInfra/50
   

  
    ####################################################################################################
    # PV_S 
    
    
    if(x1>0):
        Supra12=abs(x1-x2)/min(x1,x2)
        Supra13=abs(x1-x3)/min(x1,x3)   
        Supra14=abs(x1-x4)/min(x1,x4)
        Supra15=abs(x1-x5)/min(x1,x5)  
        Supra16=abs(x1-x6)/min(x1,x6)
        Supra17=abs(x1-x7)/min(x1,x7)  
        Supra18=abs(x1-x8)/min(x1,x8)
        Supra19=abs(x1-x9)/min(x1,x9)  
        Supra110=abs(x1-x10)/min(x1,x10)
    elif(x1==0):
        Supra12=abs(x1-x2)*constant
        Supra13=abs(x1-x3)*constant
        Supra14=abs(x1-x4)*constant
        Supra15=abs(x1-x5)*constant
        Supra16=abs(x1-x6)*constant
        Supra17=abs(x1-x7)*constant
        Supra18=abs(x1-x8)*constant
        Supra19=abs(x1-x9)*constant
        Supra110=abs(x1-x10)*constant 
        
    if(x2>0):
        Supra23=abs(x2-x3)/min(x2,x3)
        Supra24=abs(x2-x4)/min(x2,x4)
        Supra25=abs(x2-x5)/min(x2,x5)
        Supra26=abs(x2-x6)/min(x2,x6)
        Supra27=abs(x2-x7)/min(x2,x7)
        Supra28=abs(x2-x8)/min(x2,x8)
        Supra29=abs(x2-x9)/min(x2,x9)
        Supra210=abs(x2-x10)/min(x2,x10)
        
    elif(x2==0):
        Supra23=abs(x2-x3)*constant
        Supra24=abs(x2-x4)*constant
        Supra25=abs(x2-x5)*constant
        Supra26=abs(x2-x6)*constant
        Supra27=abs(x2-x7)*constant
        Supra28=abs(x2-x8)*constant
        Supra29=abs(x2-x9)*constant
        Supra210=abs(x2-x10)*constant
    if(x3>0):
        Supra34=abs(x3-x4)/min(x3,x4)
        Supra35=abs(x3-x5)/min(x3,x5)
        Supra36=abs(x3-x6)/min(x3,x6)
        Supra37=abs(x3-x7)/min(x3,x7)
        Supra38=abs(x3-x8)/min(x3,x8)
        Supra39=abs(x3-x9)/min(x3,x9)
        Supra310=abs(x3-x10)/min(x3,x10)      
    elif(x3==0):
        Supra34=abs(x3-x4)*constant
        Supra35=abs(x3-x5)*constant
        Supra36=abs(x3-x6)*constant
        Supra37=abs(x3-x7)*constant
        Supra38=abs(x3-x8)*constant
        Supra39=abs(x3-x9)*constant
        Supra310=abs(x3-x10)*constant
    if(x4>0):
        Supra45=abs(x4-x5)/min(x4,x5)
        Supra46=abs(x4-x6)/min(x4,x6)
        Supra47=abs(x4-x7)/min(x4,x7)
        Supra48=abs(x4-x8)/min(x4,x8)
        Supra49=abs(x4-x9)/min(x4,x9)
        Supra410=abs(x4-x10)/min(x4,x10)
    elif(x4==0):
        Supra45=abs(x4-x5)*constant
        Supra46=abs(x4-x6)*constant
        Supra47=abs(x4-x7)*constant
        Supra48=abs(x4-x8)*constant
        Supra49=abs(x4-x9)*constant
        Supra410=abs(x4-x10)*constant
    
    if(x5>0):
        Supra56=abs(x5-x6)/min(x5,x6)
        Supra57=abs(x5-x7)/min(x5,x7)
        Supra58=abs(x5-x8)/min(x5,x8)
        Supra59=abs(x5-x9)/min(x5,x9)
        Supra510=abs(x5-x10)/min(x5,x10)
    elif(x5==0):
        Supra56=abs(x5-x6)*constant
        Supra57=abs(x5-x7)*constant
        Supra58=abs(x5-x8)*constant
        Supra59=abs(x5-x9)*constant
        Supra510=abs(x5-x10)*constant
    if(x6>0):
        Supra67=abs(x6-x7)/min(x6,x7)
        Supra68=abs(x6-x8)/min(x6,x8)
        Supra69=abs(x6-x9)/min(x6,x9)
        Supra610=abs(x6-x10)/min(x6,x10)
    elif(x6==0):
        Supra67=abs(x6-x7)*constant
        Supra68=abs(x6-x8)*constant
        Supra69=abs(x6-x9)*constant
        Supra610=abs(x6-x10)*constant
    if(x7>0):
        Supra78=abs(x7-x8)/min(x7,x8)
        Supra79=abs(x7-x9)/min(x7,x9)
        Supra710=abs(x7-x10)/min(x7,x10)
    elif(x7==0):
        Supra78=abs(x7-x8)*constant
        Supra79=abs(x7-x9)*constant
        Supra710=abs(x7-x10)*constant
    if(x8>0):
        Supra89=abs(x8-x9)/min(x8,x9)
        Supra810=abs(x8-x10)/min(x8,x10)
    elif(x8==0):
        Supra89=abs(x8-x9)*constant
        Supra810=abs(x8-x10)*constant
    if(x9>0):
        Supra910=abs(x9-x10)/min(x9,x10)
    elif(x9==0):
        Supra910=abs(x9-x10)*constant
    
  

    SumSupra=(Supra12+Supra13+Supra14+Supra15+Supra16+Supra17+Supra18+Supra19+Supra110+
               Supra23+Supra24+Supra25+Supra26+Supra27+Supra28+Supra29+Supra210+
               Supra34+Supra35+Supra36+Supra37+Supra38+Supra39+Supra310+
               Supra45+Supra46+Supra47+Supra48+Supra49+Supra410+
               Supra56+Supra57+Supra58+Supra59+Supra510+
               Supra67+Supra68+Supra69+Supra610+
               Supra78+Supra79+Supra710+
               Supra89+Supra810+
               Supra910 
               )

    preSupra=(SumSupra)/50
    Supra=1-(1/(1+preSupra))
    
    
    ###############################################################################
    #PV_D
 
    preDelta=(SumSupra-SumInfra)/50
    Delta=1-(1/(1+preDelta))
   
    #############################################################################################
    #Proportional Variability
    
    prePV=(SumInfra+SumSupra)/2/50
    PV=1-(1/(1+prePV))
    
    
    #############################################################################################
    #DDI alpha4DDI 
    
    DDI12=pow(Infra12,alpha4DDI)*abs(x1-x2)
    DDI13=pow(Infra13,alpha4DDI)*abs(x1-x3)
    DDI14=pow(Infra14,alpha4DDI)*abs(x1-x4)
    DDI15=pow(Infra15,alpha4DDI)*abs(x1-x5)
    DDI16=pow(Infra16,alpha4DDI)*abs(x1-x6)
    DDI17=pow(Infra17,alpha4DDI)*abs(x1-x7)
    DDI18=pow(Infra18,alpha4DDI)*abs(x1-x8)
    DDI19=pow(Infra19,alpha4DDI)*abs(x1-x9)
    DDI110=pow(Infra110,alpha4DDI)*abs(x1-x10)
    
    DDI23=pow(Infra23,alpha4DDI)*abs(x2-x3)
    DDI24=pow(Infra24,alpha4DDI)*abs(x2-x4)
    DDI25=pow(Infra25,alpha4DDI)*abs(x2-x5)
    DDI26=pow(Infra26,alpha4DDI)*abs(x2-x6)
    DDI27=pow(Infra27,alpha4DDI)*abs(x2-x7)
    DDI28=pow(Infra28,alpha4DDI)*abs(x2-x8)
    DDI29=pow(Infra29,alpha4DDI)*abs(x2-x9)
    DDI210=pow(Infra210,alpha4DDI)*abs(x2-x10)
    
    DDI34=pow(Infra34,alpha4DDI)*abs(x3-x4)
    DDI35=pow(Infra35,alpha4DDI)*abs(x3-x5)
    DDI36=pow(Infra36,alpha4DDI)*abs(x3-x6)
    DDI37=pow(Infra37,alpha4DDI)*abs(x3-x7)
    DDI38=pow(Infra38,alpha4DDI)*abs(x3-x8)
    DDI39=pow(Infra39,alpha4DDI)*abs(x3-x9)
    DDI310=pow(Infra310,alpha4DDI)*abs(x3-x10)

    DDI45=pow(Infra45,alpha4DDI)*abs(x4-x5)
    DDI46=pow(Infra46,alpha4DDI)*abs(x4-x6)
    DDI47=pow(Infra47,alpha4DDI)*abs(x4-x7)
    DDI48=pow(Infra48,alpha4DDI)*abs(x4-x8)
    DDI49=pow(Infra49,alpha4DDI)*abs(x4-x9)
    DDI410=pow(Infra410,alpha4DDI)*abs(x4-x10)
    
    DDI56=pow(Infra56,alpha4DDI)*abs(x5-x6)
    DDI57=pow(Infra57,alpha4DDI)*abs(x5-x7)
    DDI58=pow(Infra58,alpha4DDI)*abs(x5-x8)
    DDI59=pow(Infra59,alpha4DDI)*abs(x5-x9)
    DDI510=pow(Infra510,alpha4DDI)*abs(x5-x10)
    
    DDI67=pow(Infra67,alpha4DDI)*abs(x6-x7)
    DDI68=pow(Infra68,alpha4DDI)*abs(x6-x8)
    DDI69=pow(Infra69,alpha4DDI)*abs(x6-x9)
    DDI610=pow(Infra610,alpha4DDI)*abs(x6-x10)
   
    DDI78=pow(Infra78,alpha4DDI)*abs(x7-x8)
    DDI79=pow(Infra79,alpha4DDI)*abs(x7-x9)
    DDI710=pow(Infra710,alpha4DDI)*abs(x7-x10)
    
    DDI89=pow(Infra89,alpha4DDI)*abs(x8-x9)
    DDI810=pow(Infra810,alpha4DDI)*abs(x8-x10)
    
    DDI910=pow(Infra910,alpha4DDI)*abs(x9-x10)
    
    SumDDI=(DDI12+DDI13+DDI14+DDI15+DDI16+DDI17+DDI18+DDI19+DDI110+
               DDI23+DDI24+DDI25+DDI26+DDI27+DDI28+DDI29+DDI210+
               DDI34+DDI35+DDI36+DDI37+DDI38+DDI39+DDI310+
               DDI45+DDI46+DDI47+DDI48+DDI49+DDI410+
               DDI56+DDI57+DDI58+DDI59+DDI510+
               DDI67+DDI68+DDI69+DDI610+
               DDI78+DDI79+DDI710+
               DDI89+DDI810+
               DDI910)
   
    DDI=SumDDI/50/(2*mean)

    ###############################################################################################
    
    w1 = x1/Summ
    w2 = x2/Summ
    w3 = x3/Summ
    w4 = x4/Summ
    w5 = x5/Summ
    w6 = x6/Summ
    w7 = x7/Summ
    w8 = x8/Summ
    w9 = x9/Summ
    w10 = x10/Summ
    
    percent1=round(w1*100,10)
    percent2=round(w2*100,10)
    percent3=round(w3*100,10)
    percent4=round(w4*100,10)
    percent5=round(w5*100,10)
    percent6=round(w6*100,10)
    percent7=round(w7*100,10)
    percent8=round(w8*100,10)
    percent9=round(w9*100,10)
    percent10=round(w10*100,10)
    

    value1=x1
    value2=x2
    value3=x3
    value4=x4
    value5=x5
    value6=x6
    value7=x7
    value8=x8
    value9=x9
    value10=x10
    
    
    ############################################################################################## 
    i+=1
    
    df.loc[len(df)] = (CV,SDL,Infra,DDI,Supra,Delta,PV,
                       percent1,percent2,percent3,percent4,percent5,
                       percent6,percent7,percent8,percent9,percent10,
                       value1,value2,value3,value4,value5,value6,value7,value8,value9,value10
                       )

# %%
df
# Out:
#              CV       SDL     Infra       DDI     Supra     Delta        PV  \
# 0      1.204159  0.825772  0.600000  0.582500  0.755199  0.713052  0.648194
# 1      1.064408  0.683721  0.641333  0.483509  0.704732  0.635757  0.602234
# 2      1.212079  0.683772  0.620000  0.525926  0.708274  0.643858  0.603793
# 3      0.812286  0.692081  0.606190  0.363651  0.710916  0.649494  0.605164
# 4      0.953794  0.801854  0.593333  0.461806  0.739779  0.692265  0.632097
# ...         ...       ...       ...       ...       ...       ...       ...
# 9996   1.086246  0.702889  0.632000  0.521176  0.703126  0.634561  0.600035
# 9997   0.734706  0.644579  0.550000  0.299902  0.695699  0.634532  0.586454
# 9998   0.636364  0.498944  0.492667  0.255606  0.600217  0.502163  0.499252
# 9999   0.881396  0.697797  0.613333  0.410606  0.699465  0.631549  0.595202
# 10000  0.973175  0.800931  0.608667  0.477826  0.744995  0.698142  0.638346
#
# ...

# %%
df.to_excel(r'C:/Documents/Pandas2Excel/N10_PropVars_Gini_CV_SDL_DDI_ZeroValues.xlsx', sheet_name='Sheet1', index = True)
